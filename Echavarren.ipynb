# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from google.colab import drive
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/Colab Notebooks/Machine Learning Project/Parkinson-s-Disease-Progression-Prediction

# %%
# Load all datasets
train_proteins = pd.read_csv("./input/train_proteins.csv")
train_clinical = pd.read_csv("./input/train_clinical_data.csv")
train_peptides = pd.read_csv("./input/train_peptides.csv")
supplemental_clinical = pd.read_csv("./input/supplemental_clinical_data.csv")

# %%
train_proteins.head()
# Out:
#   visit_id  visit_month  patient_id UniProt       NPX
# 0     55_0            0          55  O00391   11254.3
# 1     55_0            0          55  O00533  732430.0
# 2     55_0            0          55  O00584   39585.8
# 3     55_0            0          55  O14498   41526.9
# 4     55_0            0          55  O14773   31238.0

# %%
# Pivot the proteins and peptides tables so each protein and peptide is a feature
train_proteins = train_proteins.pivot_table(values="NPX", index="visit_id", columns="UniProt")
train_peptides = train_peptides.pivot_table(values="PeptideAbundance", index="visit_id", columns="Peptide")

# %%
# Merge the three tables
train = train_clinical.merge(train_proteins, on="visit_id", how="left")  \
                      .merge(train_peptides, on="visit_id", how="left")

# %%
# Set the patient id as index
train = train.set_index(["patient_id"])

# %%
# An overview of the new tables
train.head(20)
# Out:
#            visit_id  visit_month  updrs_1  updrs_2  updrs_3  updrs_4  \
# patient_id
# 55             55_0            0     10.0      6.0     15.0      NaN
# 55             55_3            3     10.0      7.0     25.0      NaN
# 55             55_6            6      8.0     10.0     34.0      NaN
# 55             55_9            9      8.0      9.0     30.0      0.0
# 55            55_12           12     10.0     10.0     41.0      0.0
# 55            55_18           18      7.0     13.0     38.0      0.0
# 55            55_24           24     16.0      9.0     49.0      0.0
# 55            55_30           30     14.0     13.0     49.0      0.0
# 55            55_36           36     17.0     18.0     51.0      0.0
# 55            55_42           42     12.0     20.0     41.0      0.0
# 55            55_48           48     17.0     16.0     52.0      0.0
# 55            55_54           54     12.0     18.0     51.0      0.0
# 55            55_60           60     23.0     21.0     56.0      0.0
# 942           942_0            0      3.0      2.0     20.0      NaN
# 942           942_3            3      7.0      2.0     17.0      NaN
# 942           942_6            6      8.0      2.0     21.0      NaN
# 942          942_12           12      5.0      2.0     25.0      0.0
# 942          942_18           18      6.0      5.0     18.0      0.0
# 942          942_24           24      2.0      3.0     23.0      NaN
# 942          942_30           30      4.0      4.0     19.0      0.0
#
#            upd23b_clinical_state_on_medication    O00391    O00533   O00584  \
# patient_id
# 55                                         NaN  11254.30  732430.0  39585.8
# 55                                         NaN       NaN       NaN      NaN
# 55                                         NaN  13163.60  630465.0  35220.8
# 55                                          On       NaN       NaN      NaN
# 55                                          On  15257.60  815083.0  41650.9
# 55                                          On       NaN       NaN      NaN
# 55                                          On       NaN       NaN      NaN
# 55                                          On       NaN       NaN      NaN
# 55                                          On  13530.80  753832.0  43048.9
# 55                                          On       NaN       NaN      NaN
# 55                                          On       NaN       NaN      NaN
# 55                                          On       NaN       NaN      NaN
# 55                                          On       NaN       NaN      NaN
# 942                                        NaN       NaN       NaN      NaN
# 942                                        NaN       NaN       NaN      NaN
# 942                                        NaN  11218.70  399518.0  20581.0
# 942                                        NaN   6757.32  360858.0  18367.6
# 942                                        NaN       NaN       NaN      NaN
# 942                                        NaN       NaN  352722.0  22834.9
# 942                                        NaN       NaN       NaN      NaN
#
#             ...  YSLTYIYTGLSK   YTTEIIK  YVGGQEHFAHLLILR  \
# patient_id  ...
# 55          ...      201158.0  16492.30        3810270.0
# 55          ...           NaN       NaN              NaN
# 55          ...      171079.0  13198.80        4119520.0
# 55          ...           NaN       NaN              NaN
# 55          ...      231772.0  17873.80        5474140.0
# 55          ...           NaN       NaN              NaN
# 55          ...           NaN       NaN              NaN
# 55          ...           NaN       NaN              NaN
# 55          ...      185290.0  18580.50        2659660.0
# 55          ...           NaN       NaN              NaN
# 55          ...           NaN       NaN              NaN
# 55          ...           NaN       NaN              NaN
# 55          ...           NaN       NaN              NaN
# 942         ...           NaN       NaN              NaN
# 942         ...           NaN       NaN              NaN
# 942         ...      226314.0   6399.80              NaN
# 942         ...      173259.0   4767.63         374307.0
# 942         ...           NaN       NaN              NaN
# 942         ...      185428.0   5554.53              NaN
# 942         ...           NaN       NaN              NaN
#
#             YVM(UniMod_35)LPVADQDQC(UniMod_4)IR  YVMLPVADQDQC(UniMod_4)IR  \
# patient_id
# 55                                     106894.0                  580667.0
# 55                                          NaN                       NaN
# 55                                     113385.0                  514861.0
# 55                                          NaN                       NaN
# 55                                     116286.0                  711815.0
# 55                                          NaN                       NaN
# 55                                          NaN                       NaN
# 55                                          NaN                       NaN
# 55                                      90936.9                  679163.0
# 55                                          NaN                       NaN
# 55                                          NaN                       NaN
# 55                                          NaN                       NaN
# 55                                          NaN                       NaN
# 942                                         NaN                       NaN
# 942                                         NaN                       NaN
# 942                                     57571.4                  480951.0
# 942                                     35767.3                  250397.0
# 942                                         NaN                       NaN
# 942                                     64049.8                  479473.0
# 942                                         NaN                       NaN
#
#             YVNKEIQNAVNGVK  YWGVASFLQK  YYC(UniMod_4)FQGNQFLR  YYTYLIMNK  \
# patient_id
# 55                131155.0    165851.0               437305.0    46289.2
# 55                     NaN         NaN                    NaN        NaN
# 55                103512.0    144607.0               457891.0    40047.7
# 55                     NaN         NaN                    NaN        NaN
# 55                136943.0    181763.0               452253.0    54725.1
# 55                     NaN         NaN                    NaN        NaN
# 55                     NaN         NaN                    NaN        NaN
# 55                     NaN         NaN                    NaN        NaN
# 55                128593.0    203680.0               498621.0    52792.7
# 55                     NaN         NaN                    NaN        NaN
# 55                     NaN         NaN                    NaN        NaN
# 55                     NaN         NaN                    NaN        NaN
# 55                     NaN         NaN                    NaN        NaN
# 942                    NaN         NaN                    NaN        NaN
# 942                    NaN         NaN                    NaN        NaN
# 942                80001.2     79661.9               573300.0    48005.8
# 942                65966.9     77976.8               486239.0    45032.7
# 942                    NaN         NaN                    NaN        NaN
# 942                68505.7     74483.1               561398.0    52916.4
# 942                    NaN         NaN                    NaN        NaN
#
#             YYWGGQYTWDMAK
# patient_id
# 55                14898.4
# 55                    NaN
# 55                20703.9
# 55                    NaN
# 55                21841.1
# 55                    NaN
# 55                    NaN
# 55                    NaN
# 55                13973.7
# 55                    NaN
# 55                    NaN
# 55                    NaN
# 55                    NaN
# 942                   NaN
# 942                   NaN
# 942               15674.1
# 942                   NaN
# 942                   NaN
# 942               21847.6
# 942                   NaN
#
# [20 rows x 1202 columns]

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2615 entries, 55 to 65043
# Columns: 1202 entries, visit_id to YYWGGQYTWDMAK
# dtypes: float64(1199), int64(1), object(2)
# memory usage: 24.0+ MB

# %%
train = train.drop("visit_id", axis=1)

# %%
# Create a list of the ids of the patients
patient_id = list(train.index.unique())

# %%
# Check missing values
print(train.isna().sum().sum())
# Out:
# 1962306

# %%
# Interpolate the missing data of every patient
for patient in patient_id:
    train.loc[patient] = train.loc[patient].interpolate(method="linear").fillna(method="bfill")

# %%
# Fill updrs and state of medication values
train.updrs_4 = train.updrs_4.fillna(0)
train.upd23b_clinical_state_on_medication = train.upd23b_clinical_state_on_medication.fillna("Off")

# %%
# Adjust updr4 values to possible values
train.updrs_4 = round(train.updrs_4)

# %%
# Check missing values after interpolate
print("Total missing values left: {}".format(train.isna().sum().sum()))
print(train.isna().sum().sort_values(ascending=False))
# Out:
# Total missing values left: 80927
# EPQVYTLPPSRDELTK                                       1230
# ALVQQMEQLR                                              778
# AVGDKLPEC(UniMod_4)EADDGC(UniMod_4)PKPPEIAHGYVEHSVR     741
# HYEGSTVPEK                                              683
# QQLVETHMAR                                              662
#                                                        ...
# DDNPNLPR                                                  0
# DFADIPNLR                                                 0
# DIPMNPMC(UniMod_4)IYR                                     0
# DKLAAC(UniMod_4)LEGNC(UniMod_4)AEGLGTNYR                  0
# visit_month                                               0
# Length: 1201, dtype: int64

# %%
# Fill the remaining na values with the mean of the columns
train = train.fillna(train.mean())
# Out:
# <ipython-input-18-081beb35b675>:2: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   train = train.fillna(train.mean())

# %%
train.head(20)
# Out:
#             visit_month  updrs_1  updrs_2  updrs_3  updrs_4  \
# patient_id
# 55                    0     10.0      6.0     15.0      0.0
# 55                    3     10.0      7.0     25.0      0.0
# 55                    6      8.0     10.0     34.0      0.0
# 55                    9      8.0      9.0     30.0      0.0
# 55                   12     10.0     10.0     41.0      0.0
# 55                   18      7.0     13.0     38.0      0.0
# 55                   24     16.0      9.0     49.0      0.0
# 55                   30     14.0     13.0     49.0      0.0
# 55                   36     17.0     18.0     51.0      0.0
# 55                   42     12.0     20.0     41.0      0.0
# 55                   48     17.0     16.0     52.0      0.0
# 55                   54     12.0     18.0     51.0      0.0
# 55                   60     23.0     21.0     56.0      0.0
# 942                   0      3.0      2.0     20.0      0.0
# 942                   3      7.0      2.0     17.0      0.0
# 942                   6      8.0      2.0     21.0      0.0
# 942                  12      5.0      2.0     25.0      0.0
# 942                  18      6.0      5.0     18.0      0.0
# 942                  24      2.0      3.0     23.0      0.0
# 942                  30      4.0      4.0     19.0      0.0
#
#            upd23b_clinical_state_on_medication        O00391     O00533  \
# patient_id
# 55                                          On  11254.300000  732430.00
# 55                                          On  12208.950000  681447.50
# 55                                          On  13163.600000  630465.00
# 55                                          On  14210.600000  722774.00
# 55                                          On  15257.600000  815083.00
# 55                                          On  14825.900000  799770.25
# 55                                          On  14394.200000  784457.50
# 55                                          On  13962.500000  769144.75
# 55                                          On  13530.800000  753832.00
# 55                                          On  13530.800000  753832.00
# 55                                          On  13530.800000  753832.00
# 55                                          On  13530.800000  753832.00
# 55                                          On  13530.800000  753832.00
# 942                                        Off  11218.700000  399518.00
# 942                                        Off  11218.700000  399518.00
# 942                                        Off  11218.700000  399518.00
# 942                                        Off   6757.320000  360858.00
# 942                                        Off   7569.066667  356790.00
# 942                                        Off   8380.813333  352722.00
# 942                                        Off   9192.560000  327496.50
#
#               O00584     O14498  ...  YSLTYIYTGLSK    YTTEIIK  \
# patient_id                       ...
# 55          39585.80  41526.900  ...     201158.00  16492.300
# 55          37403.30  41410.950  ...     186118.50  14845.550
# 55          35220.80  41295.000  ...     171079.00  13198.800
# 55          38435.85  40529.150  ...     201425.50  15536.300
# 55          41650.90  39763.300  ...     231772.00  17873.800
# 55          42000.40  40698.375  ...     220151.50  18050.475
# 55          42349.90  41633.450  ...     208531.00  18227.150
# 55          42699.40  42568.525  ...     196910.50  18403.825
# 55          43048.90  43503.600  ...     185290.00  18580.500
# 55          43048.90  43503.600  ...     185290.00  18580.500
# 55          43048.90  43503.600  ...     185290.00  18580.500
# 55          43048.90  43503.600  ...     185290.00  18580.500
# 55          43048.90  43503.600  ...     185290.00  18580.500
# 942         20581.00  31290.900  ...     226314.00   6399.800
# 942         20581.00  31290.900  ...     226314.00   6399.800
# 942         20581.00  31290.900  ...     226314.00   6399.800
# 942         18367.60  14760.700  ...     173259.00   4767.630
# 942         20601.25  19076.900  ...     179343.50   5161.080
# 942         22834.90  23393.100  ...     185428.00   5554.530
# 942         22637.80  24134.950  ...     173473.75   5743.420
#
#             YVGGQEHFAHLLILR  YVM(UniMod_35)LPVADQDQC(UniMod_4)IR  \
# patient_id
# 55                3810270.0                           106894.000
# 55                3964895.0                           110139.500
# 55                4119520.0                           113385.000
# 55                4796830.0                           114835.500
# 55                5474140.0                           116286.000
# 55                4770520.0                           109948.725
# 55                4066900.0                           103611.450
# 55                3363280.0                            97274.175
# 55                2659660.0                            90936.900
# 55                2659660.0                            90936.900
# 55                2659660.0                            90936.900
# 55                2659660.0                            90936.900
# 55                2659660.0                            90936.900
# 942                374307.0                            57571.400
# 942                374307.0                            57571.400
# 942                374307.0                            57571.400
# 942                374307.0                            35767.300
# 942                374307.0                            49908.550
# 942                374307.0                            64049.800
# 942                374307.0                            55039.550
#
#             YVMLPVADQDQC(UniMod_4)IR  YVNKEIQNAVNGVK  YWGVASFLQK  \
# patient_id
# 55                          580667.0      131155.000  165851.000
# 55                          547764.0      117333.500  155229.000
# 55                          514861.0      103512.000  144607.000
# 55                          613338.0      120227.500  163185.000
# 55                          711815.0      136943.000  181763.000
# 55                          703652.0      134855.500  187242.250
# 55                          695489.0      132768.000  192721.500
# 55                          687326.0      130680.500  198200.750
# 55                          679163.0      128593.000  203680.000
# 55                          679163.0      128593.000  203680.000
# 55                          679163.0      128593.000  203680.000
# 55                          679163.0      128593.000  203680.000
# 55                          679163.0      128593.000  203680.000
# 942                         480951.0       80001.200   79661.900
# 942                         480951.0       80001.200   79661.900
# 942                         480951.0       80001.200   79661.900
# 942                         250397.0       65966.900   77976.800
# 942                         364935.0       67236.300   76229.950
# 942                         479473.0       68505.700   74483.100
# 942                         417444.5       67195.725   72012.775
#
#             YYC(UniMod_4)FQGNQFLR  YYTYLIMNK  YYWGGQYTWDMAK
# patient_id
# 55                       437305.0  46289.200   14898.400000
# 55                       447598.0  43168.450   17801.150000
# 55                       457891.0  40047.700   20703.900000
# 55                       455072.0  47386.400   21272.500000
# 55                       452253.0  54725.100   21841.100000
# 55                       463845.0  54242.000   19874.250000
# 55                       475437.0  53758.900   17907.400000
# 55                       487029.0  53275.800   15940.550000
# 55                       498621.0  52792.700   13973.700000
# 55                       498621.0  52792.700   13973.700000
# 55                       498621.0  52792.700   13973.700000
# 55                       498621.0  52792.700   13973.700000
# 55                       498621.0  52792.700   13973.700000
# 942                      573300.0  48005.800   15674.100000
# 942                      573300.0  48005.800   15674.100000
# 942                      573300.0  48005.800   15674.100000
# 942                      486239.0  45032.700   17731.933333
# 942                      523818.5  48974.550   19789.766667
# 942                      561398.0  52916.400   21847.600000
# 942                      579244.0  52468.225   21560.775000
#
# [20 rows x 1201 columns]

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2615 entries, 55 to 65043
# Columns: 1201 entries, visit_month to YYWGGQYTWDMAK
# dtypes: float64(1199), int64(1), object(1)
# memory usage: 24.0+ MB

# %%
s = train.columns.values
e = ['upd23b_clinical_state_on_medication', 'visit_month']
norm_columns = set(train.columns.values)-set(e)
print(len(set(train.columns.values)))
print(len(set(train.columns.values)-set(e)))
# Out:
# 1201
# 1199

# %%
# Now we shall normalize all the columns values with the exception of two columns
updrs_cols = ['updrs_1','updrs_2','updrs_3','updrs_4']
for col in norm_columns:
    train[col] = (train[col] - train[col].min()) / (train[col].max() - train[col].min())    

train.head()
# Out:
#             visit_month   updrs_1  updrs_2   updrs_3  updrs_4  \
# patient_id
# 55                    0  0.303030    0.150  0.174419      0.0
# 55                    3  0.303030    0.175  0.290698      0.0
# 55                    6  0.242424    0.250  0.395349      0.0
# 55                    9  0.242424    0.225  0.348837      0.0
# 55                   12  0.303030    0.250  0.476744      0.0
#
#            upd23b_clinical_state_on_medication    O00391    O00533    O00584  \
# patient_id
# 55                                          On  0.506663  0.385009  0.589438
# 55                                          On  0.553258  0.355831  0.555836
# 55                                          On  0.599854  0.326652  0.522234
# 55                                          On  0.650957  0.379483  0.571733
# 55                                          On  0.702060  0.432313  0.621233
#
#               O14498  ...  YSLTYIYTGLSK   YTTEIIK  YVGGQEHFAHLLILR  \
# patient_id            ...
# 55          0.577661  ...      0.475128  0.592219         0.266399
# 55          0.575605  ...      0.437318  0.532145         0.277691
# 55          0.573549  ...      0.399509  0.472072         0.288983
# 55          0.559971  ...      0.475800  0.557344         0.338447
# 55          0.546393  ...      0.552091  0.642616         0.387911
#
#             YVM(UniMod_35)LPVADQDQC(UniMod_4)IR  YVMLPVADQDQC(UniMod_4)IR  \
# patient_id
# 55                                     0.148896                  0.144114
# 55                                     0.153454                  0.135841
# 55                                     0.158013                  0.127568
# 55                                     0.160050                  0.152329
# 55                                     0.162088                  0.177089
#
#             YVNKEIQNAVNGVK  YWGVASFLQK  YYC(UniMod_4)FQGNQFLR  YYTYLIMNK  \
# patient_id
# 55                0.519776    0.626289               0.454550   0.395872
# 55                0.464635    0.585936               0.465535   0.364930
# 55                0.409494    0.545584               0.476519   0.333988
# 55                0.476181    0.616161               0.473511   0.406751
# 55                0.542868    0.686737               0.470502   0.479514
#
#             YYWGGQYTWDMAK
# patient_id
# 55               0.202879
# 55               0.244856
# 55               0.286832
# 55               0.295055
# 55               0.303277
#
# [5 rows x 1201 columns]

# %%
# We shall plot the evoltion of each updrs in time
patient = patient_id[0]
train.loc[patient].plot(x="visit_month", y=updrs_cols,
        kind="line", figsize=(10, 10))
plt.title(f'Historiogram of UPDRSs of Patient #{patient}')
plt.show()

# %%
#  We shall define a linear regression method for each updrs
def linear_regressor_method(X,Y):
    linear_regressor = LinearRegression()  # create object for the class
    linear_regressor.fit(X, Y)  # perform linear regression
    return linear_regressor

# %%
# Estimating updrs of one patient based on month_visit
# We shall invoke previous method 
linear_regressors_list = []
fig, axs = plt.subplots(2, 2,figsize=(10,10))
aux = 0
for idx, updrs in enumerate(updrs_cols):
    np_x = train.loc[patient]['visit_month'].values.reshape(-1, 1)
    np_y = train.loc[patient][updrs].values.reshape(-1, 1) 
    lr = linear_regressor_method(np_x, np_y)
    if(aux == 2):
        aux = 0
    axs[idx//2, aux].scatter(np_x,  np_y)
    axs[idx//2, aux].plot(np_x, lr.predict(np_x), color='red')
    axs[idx//2, aux].set_title(f'Historiogram of UPDRSs of Patient #{patient}')
    aux += 1

#TODO: Need to apply linear regression with all the proteins in the dataframe

# %%
training_length = round(len(patient_id)*0.8)
testing_length  = len(patient_id)-round(len(patient_id)*0.8)
train_lr = patient_id[0:training_length]
test_lr  = patient_id[training_length:len(patient_id)]

linear_regressors_list = []

print('Training set metrics:')
for idx, updrs in enumerate(updrs_cols):
    np_x = train.loc[train_lr]['visit_month'].values.reshape(-1, 1)
    np_y = train.loc[train_lr][updrs].values.reshape(-1, 1)
    lr = linear_regressor_method(np_x, np_y)
    org_dict = { f'{updrs}': lr }
    linear_regressors_list.append(org_dict)
    y_pred = lr.predict(np_x)
    mse_train = mean_squared_error(np_y, y_pred)
    mae_train = mean_absolute_error(np_y, y_pred)
    # mape_train = mean_absolute_percentage_error(np_y, y_pred) * 100
    r2_train = r2_score(np_y, y_pred)
    print(f"\tTraining set of {updrs} mean squared error: {mse_train:.2f}")
    print(f"\tTraining set of {updrs} mean absolute error: {mae_train:.2f}")
    # print(f"\tTraining set of {updrs} mean absolute percentage error: {mape_train:.3f} %")
    print(f"\tTraining set of {updrs} R^2 score: {r2_train:.2f}")

fig, axs = plt.subplots(2, 2,figsize=(10,10))
aux = 0
print('Testing set metrics:')
for idx, updrs in enumerate(updrs_cols):
    np_x = train.loc[test_lr]['visit_month'].values.reshape(-1, 1)
    np_y = train.loc[test_lr][updrs].values.reshape(-1, 1)
    lr   = linear_regressors_list[idx][f'{updrs}']
    # print(linear_regressors_list)
    y_pred = lr.predict(np_x)
    mse_test = mean_squared_error(np_y, y_pred)
    mae_test = mean_absolute_error(np_y, y_pred)
    # mape_test = mean_absolute_percentage_error(np_y, y_pred) * 100
    r2_test = r2_score(np_y, y_pred)
    print(f"\tTesting set of {updrs} mean squared error: {mse_test:.2f}")
    print(f"\tTesting set of {updrs} mean absolute error: {mae_test:.2f}")
    # print(f"\tTesting set of {updrs} mean absolute percentage error: {mape_test:.3f} %")
    print(f"\tTesting set of {updrs} R^2 score: {r2_test:.2f}")
    if(aux == 2):
        aux = 0
    axs[idx//2, aux].scatter(np_x,  np_y)
    axs[idx//2, aux].plot(np_x, lr.predict(np_x), color='red')
    axs[idx//2, aux].set_title(f'Historiogram of UPDRSs of test group')
    aux += 1

# Save the figure
fig.savefig("lr-all-updrs.png")
# Out:
# Training set metrics:
# 	Training set of updrs_1 mean squared error: 0.03
# 	Training set of updrs_1 mean absolute error: 0.13
# 	Training set of updrs_1 R^2 score: 0.01
# 	Training set of updrs_2 mean squared error: 0.03
# 	Training set of updrs_2 mean absolute error: 0.13
# 	Training set of updrs_2 R^2 score: 0.01
# 	Training set of updrs_3 mean squared error: 0.03
# 	Training set of updrs_3 mean absolute error: 0.14
# 	Training set of updrs_3 R^2 score: 0.01
# 	Training set of updrs_4 mean squared error: 0.02
# 	Training set of updrs_4 mean absolute error: 0.09
# 	Training set of updrs_4 R^2 score: 0.03
# Testing set metrics:
# 	Testing set of updrs_1 mean squared error: 0.03
# 	Testing set of updrs_1 mean absolute error: 0.12
# 	Testing set of updrs_1 R^2 score: 0.02
# 	Testing set of updrs_2 mean squared error: 0.02
# 	Testing set of updrs_2 mean absolute error: 0.12
# 	Testing set of updrs_2 R^2 score: 0.04
# 	Testing set of updrs_3 mean squared error: 0.03
# 	Testing set of updrs_3 mean absolute error: 0.14
# 	Testing set of updrs_3 R^2 score: 0.03
# 	Testing set of updrs_4 mean squared error: 0.01
# 	Testing set of updrs_4 mean absolute error: 0.08
# 	Testing set of updrs_4 R^2 score: -0.01

# %%
# Estimate linear regression of evolution od UPDRS over time on each patient

linear_regressors_list = np.zeros(shape=(8,len(patient_id)))

for patient_number, patient in enumerate(patient_id):
    print('Training set metrics:')
    print('Patient number:', patient_number)
    for idx, updrs in enumerate(updrs_cols):
        np_x = train.loc[patient]['visit_month'].values.reshape(-1, 1)
        np_y = train.loc[patient][updrs].values.reshape(-1, 1)
        lr = linear_regressor_method(np_x, np_y)
        org_dict = { f'{updrs}': lr }
        linear_regressors_list[idx,patient_number] = lr.intercept_
        linear_regressors_list[2*idx,patient_number] = lr.coef_
        y_pred = lr.predict(np_x)
        mse_train = mean_squared_error(np_y, y_pred)
        mae_train = mean_absolute_error(np_y, y_pred)
        # mape_train = mean_absolute_percentage_error(np_y, y_pred) * 100
        r2_train = r2_score(np_y, y_pred)
        print(f"\tTraining set of {updrs} mean squared error: {mse_train:.2f}")
        print(f"\tTraining set of {updrs} mean absolute error: {mae_train:.2f}")
        # print(f"\tTraining set of {updrs} mean absolute percentage error: {mape_train:.3f} %")
        print(f"\tTraining set of {updrs} R^2 score: {r2_train:.2f}")
# Out:
# Training set metrics:
# Patient number: 0
# 	Training set of updrs_1 mean squared error: 0.01
# 	Training set of updrs_1 mean absolute error: 0.07
# 	Training set of updrs_1 R^2 score: 0.57
# 	Training set of updrs_2 mean squared error: 0.00
# 	Training set of updrs_2 mean absolute error: 0.04
# 	Training set of updrs_2 R^2 score: 0.85
# 	Training set of updrs_3 mean squared error: 0.00
# 	Training set of updrs_3 mean absolute error: 0.06
# 	Training set of updrs_3 R^2 score: 0.73
# 	Training set of updrs_4 mean squared error: 0.00
# 	Training set of updrs_4 mean absolute error: 0.00
# 	Training set of updrs_4 R^2 score: 1.00
# Training set metrics:
# Patient number: 1
# 	Training set of updrs_1 mean squared error: 0.00
# 	Training set of updrs_1 mean absolute error: 0.05
# 	Training set of updrs_1 R^2 score: 0.06
# 	Training set of updrs_2 mean squared error: 0.00
# 	Training set of updrs_2 mean absolute error: 0.02
# 	Training set of updrs_2 R^2 score: 0.57
# 	Training set of updrs_3 mean squared error: 0.00
# 	Training set of updrs_3 mean absolute error: 0.04
# 	Training set of updrs_3 R^2 score: 0.59
# 	Training set of updrs_4 mean squared error: 0.00
# 	Training set of updrs_4 mean absolute error: 0.02
# 	Training set of updrs_4 R^2 score: 0.28
# Training set metrics:
# Patient number: 2
# 	Training set of updrs_1 mean squared error: 0.01
# 	Training set of updrs_1 mean absolute error: 0.07
# 	Training set of updrs_1 R^2 score: 0.10
# 	Training set of updrs_2 mean squared error: 0.00
# 	Training set of updrs_2 mean absolute error: 0.05
# 	Training set of updrs_2 R^2 score: 0.75
# 	Training set of updrs_3 mean squared error: 0.00
# 	Training set of updrs_3 mean absolute error: 0.03
# 	Training set of updrs_3 R^2 score: 0.62
# 	Training set of updrs_4 mean squared error: 0.01
# 	Training set of updrs_4 mean absolute error: 0.09
# 	Training set of updrs_4 R^2 score: 0.17
# Training set metrics:
# Patient number: 3
# 	Training set of updrs_1 mean squared error: 0.00
# 	Training set of updrs_1 mean absolute error: 0.01
# 	Training set of updrs_1 R^2 score: 0.45
# 	Training set of updrs_2 mean squared error: 0.00
# 	Training set of updrs_2 mean absolute error: 0.01
# 	Training set of updrs_2 R^2 score: 0.00
# 	Training set of updrs_3 mean squared error: 0.00
# 	Training set of updrs_3 mean absolute error: 0.01
# 	Training set of updrs_3 R^2 score: 0.26
# 	Training set of updrs_4 mean squared error: 0.00
# 	Training set of updrs_4 mean absolute error: 0.00
# 	Training set of updrs_4 R^2 score: 1.00
# Training set metrics:
# Patient number: 4
# 	Training set of updrs_1 mean squared error: 0.00
# 	Training set of updrs_1 mean absolute error: 0.05
# 	Training set of updrs_1 R^2 score: 0.48
# 	Training set of updrs_2 mean squared error: 0.00
# 	Training set of updrs_2 mean absolute error: 0.00
# 	Training set of updrs_2 R^2 score: 1.00
# 	Training set of updrs_3 mean squared error: 0.00
# 	Training set of updrs_3 mean absolute error: 0.01
# 	Training set of updrs_3 R^2 score: 0.05
# 	Training set of updrs_4 mean squared error: 0.00
# 	Training set of updrs_4 mean absolute error: 0.00
# 	Training set of updrs_4 R^2 score: 1.00
# Training set metrics:
# Patient number: 5
# 	Training set of updrs_1 mean squared error: 0.01
# 	Training set of updrs_1 mean absolute error: 0.07
# 	Training set of updrs_1 R^2 score: 0.22
# 	Training set of updrs_2 mean squared error: 0.01
# 	Training set of updrs_2 mean absolute error: 0.06
# 	Training set of updrs_2 R^2 score: 0.25
# 	Training set of updrs_3 mean squared error: 0.00
# 	Training set of updrs_3 mean absolute error: 0.04
# 	Training set of updrs_3 R^2 score: 0.00
# 	Training set of updrs_4 mean squared error: 0.00
# 	Training set of updrs_4 mean absolute error: 0.06
# 	Training set of updrs_4 R^2 score: 0.00
# Training set metrics:
# Patient number: 6
# 	Training set of updrs_1 mean squared error: 0.00
# 	Training set of updrs_1 mean absolute error: 0.03
# 	Training set of updrs_1 R^2 score: 0.79
# 	Training set of updrs_2 mean squared error: 0.00
# 	Training set of updrs_2 mean absolute error: 0.06
# 	Training set of updrs_2 R^2 score: 0.44
# 	Training set of updrs_3 mean squared error: 0.00
# 	Training set of updrs_3 mean absolute error: 0.03
# 	Training set of updrs_3 R^2 score: 0.60
# 	Training set of updrs_4 mean squared error: 0.01
# 	Training set of updrs_4 mean absolute error: 0.07
# 	Training set of updrs_4 R^2 score: 0.11
# Training set metrics:
# Patient number: 7
# 	Training set of updrs_1 mean squared error: 0.00
# 	Training set of updrs_1 mean absolute error: 0.06
# 	Training set of updrs_1 R^2 score: 0.46
# 	Training set of updrs_2 mean squared error: 0.00
# 	Training set of updrs_2 mean absolute error: 0.04
# 	Training set of updrs_2 R^2 score: 0.90
# 	Training set of updrs_3 mean squared error: 0.00
# 	Training set of updrs_3 mean absolute error: 0.04
# 	Training set of updrs_3 R^2 score: 0.92
# 	Training set of updrs_4 mean squared error: 0.00
# 	Training set of updrs_4 mean absolute error: 0.00
# 	Training set of updrs_4 R^2 score: 1.00
# Training set metrics:
# Patient number: 8
# 	Training set of updrs_1 mean squared error: 0.00
# 	Training set of updrs_1 mean absolute error: 0.02
# 	Training set of updrs_1 R^2 score: 0.02
# 	Training set of updrs_2 mean squared error: 0.00
# 	Training set of updrs_2 mean absolute error: 0.00
# 	Training set of updrs_2 R^2 score: 1.00
# 	Training set of updrs_3 mean squared error: 0.00
# 	Training set of updrs_3 mean absolute error: 0.00
# 	Training set of updrs_3 R^2 score: 1.00
# 	Training set of updrs_4 mean squared error: 0.00
# 	Training set of updrs_4 mean absolute error: 0.00
# 	Training set of updrs_4 R^2 score: 1.00
# Training set metrics:
# Patient number: 9
# 	Training set of updrs_1 mean squared error: 0.00
# 	Training set of updrs_1 mean absolute error: 0.03
# 	Training set of updrs_1 R^2 score: 0.50
# 	Training set of updrs_2 mean squared error: 0.00
# 	Training set of updrs_2 mean absolute error: 0.02
# 	Training set of updrs_2 R^2 score: 0.42
# 	Training set of updrs_3 mean squared error: 0.00
# 	Training set of updrs_3 mean absolute error: 0.03
# 	Training set of updrs_3 R^2 score: 0.42
# 	Training set of updrs_4 mean squared error: 0.00
# 	Training set of updrs_4 mean absolute error: 0.04
# 	Training set of updrs_4 R^2 score: 0.46
# Training set metrics:
# Patient number: 10
# 	Training set of updrs_1 mean squared error: 0.00
# 	Training set of updrs_1 mean absolute error: 0.02
# 	Training set of updrs_1 R^2 score: 0.49
# 	Training set of updrs_2 mean squared error: 0.00
# 	Training set of updrs_2 mean absolute error: 0.00
# 	Training set of updrs_2 R^2 score: 1.00
# 	Training set of updrs_3 mean squared error: 0.00
# 	Training set of updrs_3 mean absolute error: 0.00
# 	Training set of updrs_3 R^2 score: 0.70
# 	Training set of updrs_4 mean squared error: 0.00
# 	Training set of updrs_4 mean absolute error: 0.00
# 	Training set of updrs_4 R^2 score: 1.00
# Training set metrics:
# Patient number: 11
# 	Training set of updrs_1 mean squared error: 0.00
# 	Training set of updrs_1 mean absolute error: 0.03
# 	Training set of updrs_1 R^2 score: 0.58
# 	Training set of updrs_2 mean squared error: 0.00
# 	Training set of updrs_2 mean absolute error: 0.01
# 	Training set of updrs_2 R^2 score: 0.08
# 	Training set of updrs_3 mean squared error: 0.00
# 	Training set of updrs_3 mean absolute error: 0.00
# 	Training set of updrs_3 R^2 score: 1.00
# 	Training set of updrs_4 mean squared error: 0.00
# 	Training set of updrs_4 mean absolute error: 0.00
# 	Training set of updrs_4 R^2 score: 1.00
# Training set metrics:
# Patient number: 12
# 	Training set of updrs_1 mean squared error: 0.01
# 	Training set of updrs_1 mean absolute error: 0.07
# 	Training set of updrs_1 R^2 score: 0.00
# 	Training set of updrs_2 mean squared error: 0.00
# 	Training set of updrs_2 mean absolute error: 0.01
# 	Training set of updrs_2 R^2 score: 0.29
# 	Training set of updrs_3 mean squared error: 0.00
# 	Training set of updrs_3 mean absolute error: 0.01
# 	Training set of updrs_3 R^2 score: 0.00
# 	Training set of updrs_4 mean squared error: 0.00
# 	Training set of updrs_4 mean absolute error: 0.00
# 	Training set of updrs_4 R^2 score: 1.00
# Training set metrics:
# Patient number: 13
# 	Training set of updrs_1 mean squared error: 0.01
# 	Training set of updrs_1 mean absolute error: 0.09
# 	Training set of updrs_1 R^2 score: 0.50
# 	Training set of updrs_2 mean squared error: 0.01
# 	Training set of updrs_2 mean absolute error: 0.08
# 	Training set of updrs_2 R^2 score: 0.39
# 	Training set of updrs_3 mean squared error: 0.01
# 	Training set of updrs_3 mean absolute error: 0.08
# 	Training set of updrs_3 R^2 score: 0.13
# 	Training set of updrs_4 mean squared error: 0.01
# 	Training set of updrs_4 mean absolute error: 0.07
# 	Training set of updrs_4 R^2 score: 0.32
# Training set metrics:
# Patient number: 14
# 	Training set of updrs_1 mean squared error: 0.00
# 	Training set of updrs_1 mean absolute error: 0.01
# 	Training set of updrs_1 R^2 score: 0.47
# 	Training set of updrs_2 mean squared error: 0.00
# 	Training set of updrs_2 mean absolute error: 0.05
# 	Training set of updrs_2 R^2 score: 0.77
# 	Training set of updrs_3 mean squared error: 0.00
# 	Training set of updrs_3 mean absolute error: 0.03
# 	Training set of updrs_3 R^2 score: 0.35
# 	Training set of updrs_4 mean squared error: 0.00
# 	Training set of updrs_4 mean absolute error: 0.00
# 	Training set of updrs_4 R^2 score: 1.00
# Training set metrics:
# Patient number: 15
# 	Training set of updrs_1 mean squared error: 0.01
# 	Training set of updrs_1 mean absolute error: 0.06
# 	Training set of updrs_1 R^2 score: 0.55
# 	Training set of updrs_2 mean squared error: 0.00
# 	Training set of updrs_2 mean absolute error: 0.04
# 	Training set of updrs_2 R^2 score: 0.72
# 	Training set of updrs_3 mean squared error: 0.00
# 	Training set of updrs_3 mean absolute error: 0.04
# 	Training set of updrs_3 R^2 score: 0.84
# 	Training set of updrs_4 mean squared error: 0.00
# 	Training set of updrs_4 mean absolute error: 0.03
# 	Training set of updrs_4 R^2 score: 0.29
# Training set metrics:
# Patient number: 16
# 	Training set of updrs_1 mean squared error: 0.01
# 	Training set of updrs_1 mean absolute error: 0.06
# 	Training set of updrs_1 R^2 score: 0.11
# 	Training set of updrs_2 mean squared error: 0.00
# 	Training set of updrs_2 mean absolute error: 0.05
# 	Training set of updrs_2 R^2 score: 0.26
# 	Training set of updrs_3 mean squared error: 0.00
# 	Training set of updrs_3 mean absolute error: 0.05
# 	Training set of updrs_3 R^2 score: 0.03
# 	Training set of updrs_4 mean squared error: 0.01
# 	Training set of updrs_4 mean absolute error: 0.06
# 	Training set of updrs_4 R^2 score: 0.56
# Training set metrics:
# Patient number: 17
# 	Training set of updrs_1 mean squared error: 0.00
# 	Training set of updrs_1 mean absolute error: 0.01
# 	Training set of updrs_1 R^2 score: 0.47
# 	Training set of updrs_2 mean squared error: 0.00
# 	Training set of updrs_2 mean absolute error: 0.02
# 	Training set of updrs_2 R^2 score: 0.04
# 	Training set of updrs_3 mean squared error: 0.00
# 	Training set of updrs_3 mean absolute error: 0.00
# 	Training set of updrs_3 R^2 score: 0.08
# 	Training set of updrs_4 mean squared error: 0.00
# 	Training set of updrs_4 mean absolute error: 0.00
# 	Training set of updrs_4 R^2 score: 1.00
# Training set metrics:
# Patient number: 18
# 	Training set of updrs_1 mean squared error: 0.01
# 	Training set of updrs_1 mean absolute error: 0.05
# 	Training set of updrs_1 R^2 score: 0.69
# 	Training set of updrs_2 mean squared error: 0.00
# 	Training set of updrs_2 mean absolute error: 0.05
# 	Training set of updrs_2 R^2 score: 0.55
# 	Training set of updrs_3 mean squared error: 0.01
# 	Training set of updrs_3 mean absolute error: 0.07
# 	Training set of updrs_3 R^2 score: 0.57
# 	Training set of updrs_4 mean squared error: 0.00
# 	Training set of updrs_4 mean absolute error: 0.04
# 	Training set of updrs_4 R^2 score: 0.26
# Training set metrics:
# Patient number: 19
# 	Training set of updrs_1 mean squared error: 0.00
# 	Training set of updrs_1 mean absolute error: 0.04
# 	Training set of updrs_1 R^2 score: 0.05
# 	Training set of updrs_2 mean squared error: 0.00
# 	Training set of updrs_2 mean absolute error: 0.00
# 	Training set of updrs_2 R^2 score: 1.00
# 	Training set of updrs_3 mean squared error: 0.00
# 	Training set of updrs_3 mean absolute error: 0.01
# 	Training set of updrs_3 R^2 score: 0.36
# 	Training set of updrs_4 mean squared error: 0.00
# 	Training set of updrs_4 mean absolute error: 0.00
# 	Training set of updrs_4 R^2 score: 1.00
# Training set metrics:
# Patient number: 20
# 	Training set of updrs_1 mean squared error: 0.00
# 	Training set of updrs_1 mean absolute error: 0.02
# 	Training set of updrs_1 R^2 score: 0.00
# 	Training set of updrs_2 mean squared error: 0.00
# 	Training set of updrs_2 mean absolute error: 0.00
# 	Training set of updrs_2 R^2 score: 1.00
# 	Training set of updrs_3 mean squared error: 0.00
# 	Training set of updrs_3 mean absolute error: 0.00
# 	Training set of updrs_3 R^2 score: 0.68
# 	Training set of updrs_4 mean squared error: 0.00
# 	Training set of updrs_4 mean absolute error: 0.00
# 	Training set of updrs_4 R^2 score: 1.00
# Training set metrics:
# Patient number: 21
# 	Training set of updrs_1 mean squared error: 0.00
# 	Training set of updrs_1 mean absolute error: 0.03
# 	Training set of updrs_1 R^2 score: 0.67
# 	Training set of updrs_2 mean squared error: 0.00
# 	Training set of updrs_2 mean absolute error: 0.03
# 	Training set of updrs_2 R^2 score: 0.15
# 	Training set of updrs_3 mean squared error: 0.00
# 	Training set of updrs_3 mean absolute error: 0.04
# 	Training set of updrs_3 R^2 score: 0.36
# 	Training set of updrs_4 mean squared error: 0.00
# 	Training set of updrs_4 mean absolute error: 0.03
# 	Training set of updrs_4 R^2 score: 0.00
# Training set metrics:
# Patient number: 22
# 	Training set of updrs_1 mean squared error: 0.00
# 	Training set of updrs_1 mean absolute error: 0.05
# 	Training set of updrs_1 R^2 score: 0.27
# 	Training set of updrs_2 mean squared error: 0.00
# 	Training set of updrs_2 mean absolute error: 0.03
# 	Training set of updrs_2 R^2 score: 0.78
# 	Training set of updrs_3 mean squared error: 0.00
# 	Training set of updrs_3 mean absolute error: 0.05
# 	Training set of updrs_3 R^2 score: 0.11
# 	Training set of updrs_4 mean squared error: 0.00
# 	Training set of updrs_4 mean absolute error: 0.00
# 	Training set of updrs_4 R^2 score: 1.00
# Training set metrics:
# Patient number: 23
# 	Training set of updrs_1 mean squared error: 0.00
# 	Training set of updrs_1 mean absolute error: 0.05
# 	Training set of updrs_1 R^2 score: 0.03
# 	Training set of updrs_2 mean squared error: 0.00
# 	Training set of updrs_2 mean absolute error: 0.01
# 	Training set of updrs_2 R^2 score: 0.43
# 	Training set of updrs_3 mean squared error: 0.00
# 	Training set of updrs_3 mean absolute error: 0.02
# 	Training set of updrs_3 R^2 score: 0.02
# 	Training set of updrs_4 mean squared error: 0.00
# 	Training set of updrs_4 mean absolute error: 0.00
# 	Training set of updrs_4 R^2 score: 1.00
# Training set metrics:
# Patient number: 24
# 	Training set of updrs_1 mean squared error: 0.00
# 	Training set of updrs_1 mean absolute error: 0.04
# 	Training set of updrs_1 R^2 score: 0.06
# 	Training set of updrs_2 mean squared error: 0.00
# 	Training set of updrs_2 mean absolute error: 0.03
# 	Training set of updrs_2 R^2 score: 0.04
# 	Training set of updrs_3 mean squared error: 0.00
# 	Training set of updrs_3 mean absolute error: 0.04
# 	Training set of updrs_3 R^2 score: 0.57
# 	Training set of updrs_4 mean squared error: 0.01
# 	Training set of updrs_4 mean absolute error: 0.06
# 	Training set of updrs_4 R^2 score: 0.24
# Training set metrics:
# Patient number: 25
# 	Training set of updrs_1 mean squared error: 0.00
# 	Training set of updrs_1 mean absolute error: 0.05
# 	Training set of updrs_1 R^2 score: 0.10
# 	Training set of updrs_2 mean squared error: 0.00
# 	Training set of updrs_2 mean absolute error: 0.03
# 	Training set of updrs_2 R^2 score: 0.03
# 	Training set of updrs_3 mean squared error: 0.00
# 	Training set of updrs_3 mean absolute error: 0.06
# 	Training set of updrs_3 R^2 score: 0.14
# 	Training set of updrs_4 mean squared error: 0.00
# 	Training set of updrs_4 mean absolute error: 0.05
# 	Training set of updrs_4 R^2 score: 0.42
# Training set metrics:
# Patient number: 26
# 	Training set of updrs_1 mean squared error: 0.00
# 	Training set of updrs_1 mean absolute error: 0.05
# 	Training set of updrs_1 R^2 score: 0.48
# 	Training set of updrs_2 mean squared error: 0.00
# 	Training set of updrs_2 mean absolute error: 0.03
# 	Training set of updrs_2 R^2 score: 0.44
# 	Training set of updrs_3 mean squared error: 0.00
# 	Training set of updrs_3 mean absolute error: 0.03
# 	Training set of updrs_3 R^2 score: 0.01
# 	Training set of updrs_4 mean squared error: 0.00
# 	Training set of updrs_4 mean absolute error: 0.03
# 	Training set of updrs_4 R^2 score: 0.44
# Training set metrics:
# Patient number: 27
# 	Training set of updrs_1 mean squared error: 0.01
# 	Training set of updrs_1 mean absolute error: 0.07
# 	Training set of updrs_1 R^2 score: 0.26
# 	Training set of updrs_2 mean squared error: 0.00
# 	Training set of updrs_2 mean absolute error: 0.03
# 	Training set of updrs_2 R^2 score: 0.14
# 	Training set of updrs_3 mean squared error: 0.00
# 	Training set of updrs_3 mean absolute error: 0.02
# 	Training set of updrs_3 R^2 score: 0.48
# 	Training set of updrs_4 mean squared error: 0.00
# 	Training set of updrs_4 mean absolute error: 0.06
# 	Training set of updrs_4 R^2 score: 0.00
# Training set metrics:
# Patient number: 28
# 	Training set of updrs_1 mean squared error: 0.00
# 	Training set of updrs_1 mean absolute error: 0.02
# 	Training set of updrs_1 R^2 score: 0.10
# 	Training set of updrs_2 mean squared error: 0.00
# 	Training set of updrs_2 mean absolute error: 0.02
# 	Training set of updrs_2 R^2 score: 0.18
# 	Training set of updrs_3 mean squared error: 0.00
# 	Training set of updrs_3 mean absolute error: 0.03
# 	Training set of updrs_3 R^2 score: 0.78
# 	Training set of updrs_4 mean squared error: 0.00
# 	Training set of updrs_4 mean absolute error: 0.00
# 	Training set of updrs_4 R^2 score: 1.00
# Training set metrics:
# Patient number: 29
# 	Training set of updrs_1 mean squared error: 0.01
# 	Training set of updrs_1 mean absolute error: 0.07
# 	Training set of updrs_1 R^2 score: 0.05
# 	Training set of updrs_2 mean squared error: 0.00
# 	Training set of updrs_2 mean absolute error: 0.06
# 	Training set of updrs_2 R^2 score: 0.00
# 	Training set of updrs_3 mean squared error: 0.01
# 	Training set of updrs_3 mean absolute error: 0.06
# 	Training set of updrs_3 R^2 score: 0.03
# 	Training set of updrs_4 mean squared error: 0.03
# 	Training set of updrs_4 mean absolute error: 0.12
# 	Training set of updrs_4 R^2 score: 0.16
# Training set metrics:
# Patient number: 30
# 	Training set of updrs_1 mean squared error: 0.00
# 	Training set of updrs_1 mean absolute error: 0.03
# 	Training set of updrs_1 R^2 score: 0.04
# 	Training set of updrs_2 mean squared error: 0.00
# 	Training set of updrs_2 mean absolute error: 0.01
# 	Training set of updrs_2 R^2 score: 0.37
# 	Training set of updrs_3 mean squared error: 0.00
# 	Training set of updrs_3 mean absolute error: 0.01
# 	Training set of updrs_3 R^2 score: 0.00
# 	Training set of updrs_4 mean squared error: 0.00
# 	Training set of updrs_4 mean absolute error: 0.00
# 	Training set of updrs_4 R^2 score: 1.00
# Training set metrics:
# Patient number: 31
# 	Training set of updrs_1 mean squared error: 0.00
# 	Training set of updrs_1 mean absolute error: 0.03
# 	Training set of updrs_1 R^2 score: 0.29
# 	Training set of updrs_2 mean squared error: 0.00
# 	Training set of updrs_2 mean absolute error: 0.04
# 	Training set of updrs_2 R^2 score: 0.38
# 	Training set of updrs_3 mean squared error: 0.00
# 	Training set of updrs_3 mean absolute error: 0.03
# 	Training set of updrs_3 R^2 score: 0.72
# 	Training set of updrs_4 mean squared error: 0.00
# 	Training set of updrs_4 mean absolute error: 0.03
# 	Training set of updrs_4 R^2 score: 0.58
# Training set metrics:
# Patient number: 32
# 	Training set of updrs_1 mean squared error: 0.00
# 	Training set of updrs_1 mean absolute error: 0.06
# 	Training set of updrs_1 R^2 score: 0.84
# 	Training set of updrs_2 mean squared error: 0.00
# 	Training set of updrs_2 mean absolute error: 0.05
# 	Training set of updrs_2 R^2 score: 0.32
# 	Training set of updrs_3 mean squared error: 0.00
# 	Training set of updrs_3 mean absolute error: 0.05
# 	Training set of updrs_3 R^2 score: 0.04
# 	Training set of updrs_4 mean squared error: 0.00
# 	Training set of updrs_4 mean absolute error: 0.00
# 	Training set of updrs_4 R^2 score: 1.00
# Training set metrics:
# Patient number: 33
# 	Training set of updrs_1 mean squared error: 0.00
# 	Training set of updrs_1 mean absolute error: 0.04
# 	Training set of updrs_1 R^2 score: 0.23
# 	Training set of updrs_2 mean squared error: 0.00
# 	Training set of updrs_2 mean absolute error: 0.01
# 	Training set of updrs_2 R^2 score: 0.62
# 	Training set of updrs_3 mean squared error: 0.00
# 	Training set of updrs_3 mean absolute error: 0.02
# 	Training set of updrs_3 R^2 score: 0.05
# 	Training set of updrs_4 mean squared error: 0.00
# 	Training set of updrs_4 mean absolute error: 0.00
# 	Training set of updrs_4 R^2 score: 1.00
# Training set metrics:
# Patient number: 34
# 	Training set of updrs_1 mean squared error: 0.00
# 	Training set of updrs_1 mean absolute error: 0.01
# 	Training set of updrs_1 R^2 score: 0.71
# 	Training set of updrs_2 mean squared error: 0.00
# 	Training set of updrs_2 mean absolute error: 0.04
# 	Training set of updrs_2 R^2 score: 0.24
# 	Training set of updrs_3 mean squared error: 0.01
# 	Training set of updrs_3 mean absolute error: 0.06
# 	Training set of updrs_3 R^2 score: 0.19
# 	Training set of updrs_4 mean squared error: 0.01
# 	Training set of updrs_4 mean absolute error: 0.07
# 	Training set of updrs_4 R^2 score: 0.09
# Training set metrics:
# Patient number: 35
# 	Training set of updrs_1 mean squared error: 0.00
# 	Training set of updrs_1 mean absolute error: 0.02
# 	Training set of updrs_1 R^2 score: 0.51
# 	Training set of updrs_2 mean squared error: 0.00
# 	Training set of updrs_2 mean absolute error: 0.01
# 	Training set of updrs_2 R^2 score: 0.37
# 	Training set of updrs_3 mean squared error: 0.00
# 	Training set of updrs_3 mean absolute error: 0.01
# 	Training set of updrs_3 R^2 score: 0.01
# 	Training set of updrs_4 mean squared error: 0.00
# 	Training set of updrs_4 mean absolute error: 0.00
# 	Training set of updrs_4 R^2 score: 1.00
# Training set metrics:
# Patient number: 36
# 	Training set of updrs_1 mean squared error: 0.01
# 	Training set of updrs_1 mean absolute error: 0.08
# 	Training set of updrs_1 R^2 score: 0.09
# 	Training set of updrs_2 mean squared error: 0.00
# 	Training set of updrs_2 mean absolute error: 0.04
# 	Training set of updrs_2 R^2 score: 0.01
# 	Training set of updrs_3 mean squared error: 0.00
# 	Training set of updrs_3 mean absolute error: 0.05
# 	Training set of updrs_3 R^2 score: 0.02
# 	Training set of updrs_4 mean squared error: 0.00
# 	Training set of updrs_4 mean absolute error: 0.00
# 	Training set of updrs_4 R^2 score: 1.00
# Training set metrics:
# Patient number: 37
# 	Training set of updrs_1 mean squared error: 0.00
# 	Training set of updrs_1 mean absolute error: 0.03
# 	Training set of updrs_1 R^2 score: 0.00
# 	Training set of updrs_2 mean squared error: 0.00
# 	Training set of updrs_2 mean absolute error: 0.00
# 	Training set of updrs_2 R^2 score: 1.00
# 	Training set of updrs_3 mean squared error: 0.00
# 	Training set of updrs_3 mean absolute error: 0.01
# 	Training set of updrs_3 R^2 score: 0.01
# 	Training set of updrs_4 mean squared error: 0.00
# 	Training set of updrs_4 mean absolute error: 0.00
# 	Training set of updrs_4 R^2 score: 1.00
# Training set metrics:
# Patient number: 38
# 	Training set of updrs_1 mean squared error: 0.00
# 	Training set of updrs_1 mean absolute error: 0.02
# 	Training set of updrs_1 R^2 score: 0.24
# 	Training set of updrs_2 mean squared error: 0.00
# 	Training set of updrs_2 mean absolute error: 0.00
# 	Training set of updrs_2 R^2 score: 1.00
# 	Training set of updrs_3 mean squared error: 0.00
# 	Training set of updrs_3 mean absolute error: 0.00
# 	Training set of updrs_3 R^2 score: 0.02
# 	Training set of updrs_4 mean squared error: 0.00
# 	Training set of updrs_4 mean absolute error: 0.00
# 	Training set of updrs_4 R^2 score: 1.00
# Training set metrics:
# Patient number: 39
# 	Training set of updrs_1 mean squared error: 0.00
# 	Training set of updrs_1 mean absolute error: 0.02
# 	Training set of updrs_1 R^2 score: 0.21
# 	Training set of updrs_2 mean squared error: 0.00
# 	Training set of updrs_2 mean absolute error: 0.01
# 	Training set of updrs_2 R^2 score: 0.07
# 	Training set of updrs_3 mean squared error: 0.00
# 	Training set of updrs_3 mean absolute error: 0.00
# 	Training set of updrs_3 R^2 score: 0.54
# 	Training set of updrs_4 mean squared error: 0.00
# 	Training set of updrs_4 mean absolute error: 0.00
# 	Training set of updrs_4 R^2 score: 1.00
# Training set metrics:
# Patient number: 40
# 	Training set of updrs_1 mean squared error: 0.00
# 	Training set of updrs_1 mean absolute error: 0.03
# 	Training set of updrs_1 R^2 score: 0.48
# 	Training set of updrs_2 mean squared error: 0.00
# 	Training set of updrs_2 mean absolute error: 0.04
# 	Training set of updrs_2 R^2 score: 0.33
# 	Training set of updrs_3 mean squared error: 0.00
# 	Training set of updrs_3 mean absolute error: 0.04
# 	Training set of updrs_3 R^2 score: 0.73
# 	Training set of updrs_4 mean squared error: 0.00
# 	Training set of updrs_4 mean absolute error: 0.04
# 	Training set of updrs_4 R^2 score: 0.35
# Training set metrics:
# Patient number: 41
# 	Training set of updrs_1 mean squared error: 0.00
# 	Training set of updrs_1 mean absolute error: 0.04
# 	Training set of updrs_1 R^2 score: 0.27
# 	Training set of updrs_2 mean squared error: 0.00
# 	Training set of updrs_2 mean absolute error: 0.03
# 	Training set of updrs_2 R^2 score: 0.59
# 	Training set of updrs_3 mean squared error: 0.00
# 	Training set of updrs_3 mean absolute error: 0.05
# 	Training set of updrs_3 R^2 score: 0.57
# 	Training set of updrs_4 mean squared error: 0.00
# 	Training set of updrs_4 mean absolute error: 0.01
# 	Training set of updrs_4 R^2 score: 0.39
# Training set metrics:
# Patient number: 42
# 	Training set of updrs_1 mean squared error: 0.00
# 	Training set of updrs_1 mean absolute error: 0.03
# 	Training set of updrs_1 R^2 score: 0.15
# 	Training set of updrs_2 mean squared error: 0.00
# 	Training set of updrs_2 mean absolute error: 0.01
# 	Training set of updrs_2 R^2 score: 0.71
# 	Training set of updrs_3 mean squared error: 0.00
# 	Training set of updrs_3 mean absolute error: 0.03
# 	Training set of updrs_3 R^2 score: 0.34
# 	Training set of updrs_4 mean squared error: 0.00
# 	Training set of updrs_4 mean absolute error: 0.00
# 	Training set of updrs_4 R^2 score: 1.00
# Training set metrics:
# Patient number: 43
# 	Training set of updrs_1 mean squared error: 0.00
# 	Training set of updrs_1 mean absolute error: 0.03
# 	Training set of updrs_1 R^2 score: 0.58
# 	Training set of updrs_2 mean squared error: 0.00
# 	Training set of updrs_2 mean absolute error: 0.02
# 	Training set of updrs_2 R^2 score: 0.30
# 	Training set of updrs_3 mean squared error: 0.00
# 	Training set of updrs_3 mean absolute error: 0.05
# 	Training set of updrs_3 R^2 score: 0.00
# 	Training set of updrs_4 mean squared error: 0.00
# 	Training set of updrs_4 mean absolute error: 0.00
# 	Training set of updrs_4 R^2 score: 1.00
# Training set metrics:
# Patient number: 44
# 	Training set of updrs_1 mean squared error: 0.01
# 	Training set of updrs_1 mean absolute error: 0.06
# 	Training set of updrs_1 R^2 score: 0.00
# 	Training set of updrs_2 mean squared error: 0.00
# 	Training set of updrs_2 mean absolute error: 0.05
# 	Training set of updrs_2 R^2 score: 0.07
# 	Training set of updrs_3 mean squared error: 0.01
# 	Training set of updrs_3 mean absolute error: 0.06
# 	Training set of updrs_3 R^2 score: 0.10
# 	Training set of updrs_4 mean squared error: 0.01
# 	Training set of updrs_4 mean absolute error: 0.07
# 	Training set of updrs_4 R^2 score: 0.05
# Training set metrics:
# Patient number: 45
# 	Training set of updrs_1 mean squared error: 0.00
# 	Training set of updrs_1 mean absolute error: 0.04
# 	Training set of updrs_1 R^2 score: 0.43
# 	Training set of updrs_2 mean squared error: 0.00
# 	Training set of updrs_2 mean absolute error: 0.02
# 	Training set of updrs_2 R^2 score: 0.03
# 	Training set of updrs_3 mean squared error: 0.00
# 	Training set of updrs_3 mean absolute error: 0.05
# 	Training set of updrs_3 R^2 score: 0.01
# 	Training set of updrs_4 mean squared error: 0.00
# 	Training set of updrs_4 mean absolute error: 0.05
# 	Training set of updrs_4 R^2 score: 0.04
# Training set metrics:
# Patient number: 46
# 	Training set of updrs_1 mean squared error: 0.00
# 	Training set of updrs_1 mean absolute error: 0.04
# 	Training set of updrs_1 R^2 score: 0.78
# 	Training set of updrs_2 mean squared error: 0.00
# 	Training set of updrs_2 mean absolute error: 0.05
# 	Training set of updrs_2 R^2 score: 0.31
# 	Training set of updrs_3 mean squared error: 0.01
# 	Training set of updrs_3 mean absolute error: 0.08
# 	Training set of updrs_3 R^2 score: 0.02
# 	Training set of updrs_4 mean squared error: 0.00
# 	Training set of updrs_4 mean absolute error: 0.05
# 	Training set of updrs_4 R^2 score: 0.49
# Training set metrics:
# Patient number: 47
# 	Training set of updrs_1 mean squared error: 0.00
# 	Training set of updrs_1 mean absolute error: 0.05
# 	Training set of updrs_1 R^2 score: 0.26
# 	Training set of updrs_2 mean squared error: 0.00
# 	Training set of updrs_2 mean absolute error: 0.02
# 	Training set of updrs_2 R^2 score: 0.13
# 	Training set of updrs_3 mean squared error: 0.00
# 	Training set of updrs_3 mean absolute error: 0.03
# 	Training set of updrs_3 R^2 score: 0.51
# 	Training set of updrs_4 mean squared error: 0.00
# 	Training set of updrs_4 mean absolute error: 0.00
# 	Training set of updrs_4 R^2 score: 1.00
# Training set metrics:
# Patient number: 48
# 	Training set of updrs_1 mean squared error: 0.00
# 	Training set of updrs_1 mean absolute error: 0.03
# 	Training set of updrs_1 R^2 score: 0.62
# 	Training set of updrs_2 mean squared error: 0.00
# 	Training set of updrs_2 mean absolute error: 0.02
# 	Training set of updrs_2 R^2 score: 0.08
# 	Training set of updrs_3 mean squared error: 0.00
# 	Training set of updrs_3 mean absolute error: 0.02
# 	Training set of updrs_3 R^2 score: 0.18
# 	Training set of updrs_4 mean squared error: 0.00
# 	Training set of updrs_4 mean absolute error: 0.00
# 	Training set of updrs_4 R^2 score: 1.00
# Training set metrics:
# Patient number: 49
# 	Training set of updrs_1 mean squared error: 0.02
# 	Training set of updrs_1 mean absolute error: 0.10
# 	Training set of updrs_1 R^2 score: 0.44
# 	Training set of updrs_2 mean squared error: 0.02
# 	Training set of updrs_2 mean absolute error: 0.10
# 	Training set of updrs_2 R^2 score: 0.16
# 	Training set of updrs_3 mean squared error: 0.02
# 	Training set of updrs_3 mean absolute error: 0.11
# 	Training set of updrs_3 R^2 score: 0.01
# 	Training set of updrs_4 mean squared error: 0.01
# 	Training set of updrs_4 mean absolute error: 0.07
# 	Training set of updrs_4 R^2 score: 0.60
# Training set metrics:
# Patient number: 50
# 	Training set of updrs_1 mean squared error: 0.01
# 	Training set of updrs_1 mean absolute error: 0.08
# 	Training set of updrs_1 R^2 score: 0.20
# 	Training set of updrs_2 mean squared error: 0.00
# 	Training set of updrs_2 mean absolute error: 0.05
# 	Training set of updrs_2 R^2 score: 0.10
# 	Training set of updrs_3 mean squared error: 0.00
# 	Training set of updrs_3 mean absolute error: 0.02
# 	Training set of updrs_3 R^2 score: 0.44
# 	Training set of updrs_4 mean squared error: 0.01
# 	Training set of updrs_4 mean absolute error: 0.09
# 	Training set of updrs_4 R^2 score: 0.10
# Training set metrics:
# Patient number: 51
# 	Training set of updrs_1 mean squared error: 0.00
# 	Training set of updrs_1 mean absolute error: 0.02
# 	Training set of updrs_1 R^2 score: 0.00
# 	Training set of updrs_2 mean squared error: 0.00
# 	Training set of updrs_2 mean absolute error: 0.03
# 	Training set of updrs_2 R^2 score: 0.38
# 	Training set of updrs_3 mean squared error: 0.00
# 	Training set of updrs_3 mean absolute error: 0.05
# 	Training set of updrs_3 R^2 score: 0.77
# 	Training set of updrs_4 mean squared error: 0.00
# 	Training set of updrs_4 mean absolute error: 0.01
# 	Training set of updrs_4 R^2 score: 0.28
# Training set metrics:
# Patient number: 52
# 	Training set of updrs_1 mean squared error: 0.00
# 	Training set of updrs_1 mean absolute error: 0.04
# 	Training set of updrs_1 R^2 score: 0.67
# 	Training set of updrs_2 mean squared error: 0.00
# 	Training set of updrs_2 mean absolute error: 0.03
# 	Training set of updrs_2 R^2 score: 0.70
# 	Training set of updrs_3 mean squared error: 0.00
# 	Training set of updrs_3 mean absolute error: 0.03
# 	Training set of updrs_3 R^2 score: 0.31
# 	Training set of updrs_4 mean squared error: 0.01
# 	Training set of updrs_4 mean absolute error: 0.07
# 	Training set of updrs_4 R^2 score: 0.76
# Training set metrics:
# Patient number: 53
# 	Training set of updrs_1 mean squared error: 0.00
# 	Training set of updrs_1 mean absolute error: 0.02
# 	Training set of updrs_1 R^2 score: 0.75
# 	Training set of updrs_2 mean squared error: 0.00
# 	Training set of updrs_2 mean absolute error: 0.00
# 	Training set of updrs_2 R^2 score: 1.00
# 	Training set of updrs_3 mean squared error: 0.00
# 	Training set of updrs_3 mean absolute error: 0.01
# 	Training set of updrs_3 R^2 score: 0.75
# 	Training set of updrs_4 mean squared error: 0.00
# 	Training set of updrs_4 mean absolute error: 0.00
# 	Training set of updrs_4 R^2 score: 1.00
# Training set metrics:
# Patient number: 54
# 	Training set of updrs_1 mean squared error: 0.01
# 	Training set of updrs_1 mean absolute error: 0.08
# 	Training set of updrs_1 R^2 score: 0.08
# 	Training set of updrs_2 mean squared error: 0.00
# 	Training set of updrs_2 mean absolute error: 0.02
# 	Training set of updrs_2 R^2 score: 0.85
# 	Training set of updrs_3 mean squared error: 0.00
# 	Training set of updrs_3 mean absolute error: 0.04
# 	Training set of updrs_3 R^2 score: 0.35
# 	Training set of updrs_4 mean squared error: 0.01
# 	Training set of updrs_4 mean absolute error: 0.06
# 	Training set of updrs_4 R^2 score: 0.20
# Training set metrics:
# Patient number: 55
# 	Training set of updrs_1 mean squared error: 0.01
# 	Training set of updrs_1 mean absolute error: 0.07
# 	Training set of updrs_1 R^2 score: 0.30
# 	Training set of updrs_2 mean squared error: 0.01
# 	Training set of updrs_2 mean absolute error: 0.08
# 	Training set of updrs_2 R^2 score: 0.46
# 	Training set of updrs_3 mean squared error: 0.00
# 	Training set of updrs_3 mean absolute error: 0.05
# 	Training set of updrs_3 R^2 score: 0.77
# 	Training set of updrs_4 mean squared error: 0.01
# 	Training set of updrs_4 mean absolute error: 0.06
# 	Training set of updrs_4 R^2 score: 0.26
# Training set metrics:
# Patient number: 56
# 	Training set of updrs_1 mean squared error: 0.00
# 	Training set of updrs_1 mean absolute error: 0.05
# 	Training set of updrs_1 R^2 score: 0.47
# 	Training set of updrs_2 mean squared error: 0.00
# 	Training set of updrs_2 mean absolute error: 0.04
# 	Training set of updrs_2 R^2 score: 0.71
# 	Training set of updrs_3 mean squared error: 0.00
# 	Training set of updrs_3 mean absolute error: 0.04
# 	Training set of updrs_3 R^2 score: 0.77
# 	Training set of updrs_4 mean squared error: 0.00
# 	Training set of updrs_4 mean absolute error: 0.04
# 	Training set of updrs_4 R^2 score: 0.02
# Training set metrics:
# Patient number: 57
# 	Training set of updrs_1 mean squared error: 0.00
# 	Training set of updrs_1 mean absolute error: 0.01
# 	Training set of updrs_1 R^2 score: 0.94
# 	Training set of updrs_2 mean squared error: 0.00
# 	Training set of updrs_2 mean absolute error: 0.01
# 	Training set of updrs_2 R^2 score: 0.12
# 	Training set of updrs_3 mean squared error: 0.01
# 	Training set of updrs_3 mean absolute error: 0.07
# 	Training set of updrs_3 R^2 score: 0.02
# 	Training set of updrs_4 mean squared error: 0.00
# 	Training set of updrs_4 mean absolute error: 0.00
# 	Training set of updrs_4 R^2 score: 1.00
# Training set metrics:
# Patient number: 58
# 	Training set of updrs_1 mean squared error: 0.00
# 	Training set of updrs_1 mean absolute error: 0.05
# 	Training set of updrs_1 R^2 score: 0.18
# 	Training set of updrs_2 mean squared error: 0.00
# 	Training set of updrs_2 mean absolute error: 0.06
# 	Training set of updrs_2 R^2 score: 0.04
# 	Training set of updrs_3 mean squared error: 0.00
# 	Training set of updrs_3 mean absolute error: 0.02
# 	Training set of updrs_3 R^2 score: 0.65
# 	Training set of updrs_4 mean squared error: 0.00
# 	Training set of updrs_4 mean absolute error: 0.00
# 	Training set of updrs_4 R^2 score: 1.00
# Training set metrics:
# Patient number: 59
# 	Training set of updrs_1 mean squared error: 0.00
# 	Training set of updrs_1 mean absolute error: 0.02
# 	Training set of updrs_1 R^2 score: 0.57
# 	Training set of updrs_2 mean squared error: 0.00
# 	Training set of updrs_2 mean absolute error: 0.02
# 	Training set of updrs_2 R^2 score: 0.01
# 	Training set of updrs_3 mean squared error: 0.00
# 	Training set of updrs_3 mean absolute error: 0.02
# 	Training set of updrs_3 R^2 score: 0.07
# 	Training set of updrs_4 mean squared error: 0.00
# 	Training set of updrs_4 mean absolute error: 0.00
# 	Training set of updrs_4 R^2 score: 1.00
# Training set metrics:
# Patient number: 60
# 	Training set of updrs_1 mean squared error: 0.00
# 	Training set of updrs_1 mean absolute error: 0.02
# 	Training set of updrs_1 R^2 score: 0.03
# 	Training set of updrs_2 mean squared error: 0.00
# 	Training set of updrs_2 mean absolute error: 0.00
# 	Training set of updrs_2 R^2 score: 1.00
# 	Training set of updrs_3 mean squared error: 0.00
# 	Training set of updrs_3 mean absolute error: 0.00
# 	Training set of updrs_3 R^2 score: 0.51
# 	Training set of updrs_4 mean squared error: 0.00
# 	Training set of updrs_4 mean absolute error: 0.00
# 	Training set of updrs_4 R^2 score: 1.00
# Training set metrics:
# Patient number: 61
# 	Training set of updrs_1 mean squared error: 0.01
# 	Training set of updrs_1 mean absolute error: 0.07
# 	Training set of updrs_1 R^2 score: 0.66
# 	Training set of updrs_2 mean squared error: 0.00
# 	Training set of updrs_2 mean absolute error: 0.05
# 	Training set of updrs_2 R^2 score: 0.26
# 	Training set of updrs_3 mean squared error: 0.02
# 	Training set of updrs_3 mean absolute error: 0.11
# 	Training set of updrs_3 R^2 score: 0.06
# 	Training set of updrs_4 mean squared error: 0.02
# 	Training set of updrs_4 mean absolute error: 0.11
# 	Training set of updrs_4 R^2 score: 0.64
# Training set metrics:
# Patient number: 62
# 	Training set of updrs_1 mean squared error: 0.00
# 	Training set of updrs_1 mean absolute error: 0.03
# 	Training set of updrs_1 R^2 score: 0.28
# 	Training set of updrs_2 mean squared error: 0.00
# 	Training set of updrs_2 mean absolute error: 0.00
# 	Training set of updrs_2 R^2 score: 1.00
# 	Training set of updrs_3 mean squared error: 0.00
# 	Training set of updrs_3 mean absolute error: 0.01
# 	Training set of updrs_3 R^2 score: 0.03
# 	Training set of updrs_4 mean squared error: 0.00
# 	Training set of updrs_4 mean absolute error: 0.00
# 	Training set of updrs_4 R^2 score: 1.00
# Training set metrics:
# Patient number: 63
# 	Training set of updrs_1 mean squared error: 0.01
# 	Training set of updrs_1 mean absolute error: 0.06
# 	Training set of updrs_1 R^2 score: 0.68
# 	Training set of updrs_2 mean squared error: 0.00
# 	Training set of updrs_2 mean absolute error: 0.05
# 	Training set of updrs_2 R^2 score: 0.26
# 	Training set of updrs_3 mean squared error: 0.00
# 	Training set of updrs_3 mean absolute error: 0.05
# 	Training set of updrs_3 R^2 score: 0.08
# 	Training set of updrs_4 mean squared error: 0.00
# 	Training set of updrs_4 mean absolute error: 0.02
# 	Training set of updrs_4 R^2 score: 0.23
# Training set metrics:
# Patient number: 64
# 	Training set of updrs_1 mean squared error: 0.01
# 	Training set of updrs_1 mean absolute error: 0.08
# 	Training set of updrs_1 R^2 score: 0.35
# 	Training set of updrs_2 mean squared error: 0.00
# 	Training set of updrs_2 mean absolute error: 0.04
# 	Training set of updrs_2 R^2 score: 0.72
# 	Training set of updrs_3 mean squared error: 0.00
# 	Training set of updrs_3 mean absolute error: 0.06
# 	Training set of updrs_3 R^2 score: 0.02
# 	Training set of updrs_4 mean squared error: 0.00
# 	Training set of updrs_4 mean absolute error: 0.03
# 	Training set of updrs_4 R^2 score: 0.02
# Training set metrics:
# Patient number: 65
# 	Training set of updrs_1 mean squared error: 0.02
# 	Training set of updrs_1 mean absolute error: 0.14
# 	Training set of updrs_1 R^2 score: 0.30
# 	Training set of updrs_2 mean squared error: 0.01
# 	Training set of updrs_2 mean absolute error: 0.08
# 	Training set of updrs_2 R^2 score: 0.54
# 	Training set of updrs_3 mean squared error: 0.00
# 	Training set of updrs_3 mean absolute error: 0.05
# 	Training set of updrs_3 R^2 score: 0.53
# 	Training set of updrs_4 mean squared error: 0.02
# 	Training set of updrs_4 mean absolute error: 0.10
# 	Training set of updrs_4 R^2 score: 0.55
# Training set metrics:
# Patient number: 66
# 	Training set of updrs_1 mean squared error: 0.00
# 	Training set of updrs_1 mean absolute error: 0.03
# 	Training set of updrs_1 R^2 score: 0.63
# 	Training set of updrs_2 mean squared error: 0.00
# 	Training set of updrs_2 mean absolute error: 0.00
# 	Training set of updrs_2 R^2 score: 0.16
# 	Training set of updrs_3 mean squared error: 0.00
# 	Training set of updrs_3 mean absolute error: 0.00
# 	Training set of updrs_3 R^2 score: 0.04
# 	Training set of updrs_4 mean squared error: 0.00
# 	Training set of updrs_4 mean absolute error: 0.00
# 	Training set of updrs_4 R^2 score: 1.00
# Training set metrics:
# Patient number: 67
# 	Training set of updrs_1 mean squared error: 0.01
# 	Training set of updrs_1 mean absolute error: 0.07
# 	Training set of updrs_1 R^2 score: 0.01
# 	Training set of updrs_2 mean squared error: 0.00
# 	Training set of updrs_2 mean absolute error: 0.01
# 	Training set of updrs_2 R^2 score: 0.37
# 	Training set of updrs_3 mean squared error: 0.00
# 	Training set of updrs_3 mean absolute error: 0.02
# 	Training set of updrs_3 R^2 score: 0.08
# 	Training set of updrs_4 mean squared error: 0.00
# 	Training set of updrs_4 mean absolute error: 0.00
# 	Training set of updrs_4 R^2 score: 1.00
# Training set metrics:
# Patient number: 68
# 	Training set of updrs_1 mean squared error: 0.00
# 	Training set of updrs_1 mean absolute error: 0.03
# 	Training set of updrs_1 R^2 score: 0.13
# 	Training set of updrs_2 mean squared error: 0.00
# 	Training set of updrs_2 mean absolute error: 0.00
# 	Training set of updrs_2 R^2 score: 1.00
# 	Training set of updrs_3 mean squared error: 0.00
# 	Training set of updrs_3 mean absolute error: 0.01
# 	Training set of updrs_3 R^2 score: 0.13
# 	Training set of updrs_4 mean squared error: 0.00
# 	Training set of updrs_4 mean absolute error: 0.00
# 	Training set of updrs_4 R^2 score: 1.00
# Training set metrics:
# Patient number: 69
# 	Training set of updrs_1 mean squared error: 0.00
# 	Training set of updrs_1 mean absolute error: 0.04
# 	Training set of updrs_1 R^2 score: 0.41
# 	Training set of updrs_2 mean squared error: 0.00
# 	Training set of updrs_2 mean absolute error: 0.03
# 	Training set of updrs_2 R^2 score: 0.50
# 	Training set of updrs_3 mean squared error: 0.00
# 	Training set of updrs_3 mean absolute error: 0.04
# 	Training set of updrs_3 R^2 score: 0.56
# 	Training set of updrs_4 mean squared error: 0.01
# 	Training set of updrs_4 mean absolute error: 0.06
# 	Training set of updrs_4 R^2 score: 0.56
# Training set metrics:
# Patient number: 70
# 	Training set of updrs_1 mean squared error: 0.00
# 	Training set of updrs_1 mean absolute error: 0.05
# 	Training set of updrs_1 R^2 score: 0.10
# 	Training set of updrs_2 mean squared error: 0.00
# 	Training set of updrs_2 mean absolute error: 0.05
# 	Training set of updrs_2 R^2 score: 0.20
# 	Training set of updrs_3 mean squared error: 0.01
# 	Training set of updrs_3 mean absolute error: 0.07
# 	Training set of updrs_3 R^2 score: 0.04
# 	Training set of updrs_4 mean squared error: 0.00
# 	Training set of updrs_4 mean absolute error: 0.02
# 	Training set of updrs_4 R^2 score: 0.78
# Training set metrics:
# Patient number: 71
# 	Training set of updrs_1 mean squared error: 0.01
# 	Training set of updrs_1 mean absolute error: 0.07
# 	Training set of updrs_1 R^2 score: 0.13
# 	Training set of updrs_2 mean squared error: 0.00
# 	Training set of updrs_2 mean absolute error: 0.03
# 	Training set of updrs_2 R^2 score: 0.19
# 	Training set of updrs_3 mean squared error: 0.00
# 	Training set of updrs_3 mean absolute error: 0.05
# 	Training set of updrs_3 R^2 score: 0.38
# 	Training set of updrs_4 mean squared error: 0.00
# 	Training set of updrs_4 mean absolute error: 0.03
# 	Training set of updrs_4 R^2 score: 0.28
# Training set metrics:
# Patient number: 72
# 	Training set of updrs_1 mean squared error: 0.00
# 	Training set of updrs_1 mean absolute error: 0.03
# 	Training set of updrs_1 R^2 score: 0.47
# 	Training set of updrs_2 mean squared error: 0.00
# 	Training set of updrs_2 mean absolute error: 0.02
# 	Training set of updrs_2 R^2 score: 0.12
# 	Training set of updrs_3 mean squared error: 0.00
# 	Training set of updrs_3 mean absolute error: 0.03
# 	Training set of updrs_3 R^2 score: 0.14
# 	Training set of updrs_4 mean squared error: 0.00
# 	Training set of updrs_4 mean absolute error: 0.00
# 	Training set of updrs_4 R^2 score: 1.00
# Training set metrics:
# Patient number: 73
# 	Training set of updrs_1 mean squared error: 0.01
# 	Training set of updrs_1 mean absolute error: 0.08
# 	Training set of updrs_1 R^2 score: 0.00
# 	Training set of updrs_2 mean squared error: 0.01
# 	Training set of updrs_2 mean absolute error: 0.09
# 	Training set of updrs_2 R^2 score: 0.18
# 	Training set of updrs_3 mean squared error: 0.01
# 	Training set of updrs_3 mean absolute error: 0.10
# 	Training set of updrs_3 R^2 score: 0.23
# 	Training set of updrs_4 mean squared error: 0.01
# 	Training set of updrs_4 mean absolute error: 0.05
# 	Training set of updrs_4 R^2 score: 0.23
# Training set metrics:
# Patient number: 74
# 	Training set of updrs_1 mean squared error: 0.00
# 	Training set of updrs_1 mean absolute error: 0.02
# 	Training set of updrs_1 R^2 score: 0.22
# 	Training set of updrs_2 mean squared error: 0.00
# 	Training set of updrs_2 mean absolute error: 0.01
# 	Training set of updrs_2 R^2 score: 0.10
# 	Training set of updrs_3 mean squared error: 0.00
# 	Training set of updrs_3 mean absolute error: 0.01
# 	Training set of updrs_3 R^2 score: 0.03
# 	Training set of updrs_4 mean squared error: 0.00
# 	Training set of updrs_4 mean absolute error: 0.00
# 	Training set of updrs_4 R^2 score: 1.00
# Training set metrics:
# Patient number: 75
# 	Training set of updrs_1 mean squared error: 0.00
# 	Training set of updrs_1 mean absolute error: 0.02
# 	Training set of updrs_1 R^2 score: 0.01
# 	Training set of updrs_2 mean squared error: 0.00
# 	Training set of updrs_2 mean absolute error: 0.00
# 	Training set of updrs_2 R^2 score: 1.00
# 	Training set of updrs_3 mean squared error: 0.00
# 	Training set of updrs_3 mean absolute error: 0.01
# 	Training set of updrs_3 R^2 score: 0.17
# 	Training set of updrs_4 mean squared error: 0.00
# 	Training set of updrs_4 mean absolute error: 0.00
# 	Training set of updrs_4 R^2 score: 1.00
# Training set metrics:
# Patient number: 76
# 	Training set of updrs_1 mean squared error: 0.01
# 	Training set of updrs_1 mean absolute error: 0.06
# 	Training set of updrs_1 R^2 score: 0.24
# 	Training set of updrs_2 mean squared error: 0.00
# 	Training set of updrs_2 mean absolute error: 0.05
# 	Training set of updrs_2 R^2 score: 0.36
# 	Training set of updrs_3 mean squared error: 0.01
# 	Training set of updrs_3 mean absolute error: 0.06
# 	Training set of updrs_3 R^2 score: 0.19
# 	Training set of updrs_4 mean squared error: 0.00
# 	Training set of updrs_4 mean absolute error: 0.03
# 	Training set of updrs_4 R^2 score: 0.51
# Training set metrics:
# Patient number: 77
# 	Training set of updrs_1 mean squared error: 0.00
# 	Training set of updrs_1 mean absolute error: 0.03
# 	Training set of updrs_1 R^2 score: 0.16
# 	Training set of updrs_2 mean squared error: 0.00
# 	Training set of updrs_2 mean absolute error: 0.03
# 	Training set of updrs_2 R^2 score: 0.32
# 	Training set of updrs_3 mean squared error: 0.00
# 	Training set of updrs_3 mean absolute error: 0.05
# 	Training set of updrs_3 R^2 score: 0.44
# 	Training set of updrs_4 mean squared error: 0.00
# 	Training set of updrs_4 mean absolute error: 0.03
# 	Training set of updrs_4 R^2 score: 0.47
# Training set metrics:
# Patient number: 78
# 	Training set of updrs_1 mean squared error: 0.02
# 	Training set of updrs_1 mean absolute error: 0.11
# 	Training set of updrs_1 R^2 score: 0.19
# 	Training set of updrs_2 mean squared error: 0.00
# 	Training set of updrs_2 mean absolute error: 0.05
# 	Training set of updrs_2 R^2 score: 0.38
# 	Training set of updrs_3 mean squared error: 0.01
# 	Training set of updrs_3 mean absolute error: 0.06
# 	Training set of updrs_3 R^2 score: 0.00
# ...
# 	Training set of updrs_4 mean absolute error: 0.09
# 	Training set of updrs_4 R^2 score: 0.22
# Training set metrics:
# Patient number: 222
# 	Training set of updrs_1 mean squared error: 0.01
# 	Training set of updrs_1 mean absolute error: 0.06
# 	Training set of updrs_1 R^2 score: 0.01
# 	Training set of updrs_2 mean squared error: 0.00
# 	Training set of updrs_2 mean absolute error: 0.05
# 	Training set of updrs_2 R^2 score: 0.35
# 	Training set of updrs_3 mean squared error: 0.00
# 	Training set of updrs_3 mean absolute error: 0.06
# 	Training set of updrs_3 R^2 score: 0.47
# 	Training set of updrs_4 mean squared error: 0.00
# 	Training set of updrs_4 mean absolute error: 0.05
# 	Training set of updrs_4 R^2 score: 0.31
# Training set metrics:
# Patient number: 223
# 	Training set of updrs_1 mean squared error: 0.00
# 	Training set of updrs_1 mean absolute error: 0.04
# 	Training set of updrs_1 R^2 score: 0.35
# 	Training set of updrs_2 mean squared error: 0.00
# 	Training set of updrs_2 mean absolute error: 0.02
# 	Training set of updrs_2 R^2 score: 0.55
# 	Training set of updrs_3 mean squared error: 0.00
# 	Training set of updrs_3 mean absolute error: 0.02
# 	Training set of updrs_3 R^2 score: 0.03
# 	Training set of updrs_4 mean squared error: 0.00
# 	Training set of updrs_4 mean absolute error: 0.00
# 	Training set of updrs_4 R^2 score: 1.00
# Training set metrics:
# Patient number: 224
# 	Training set of updrs_1 mean squared error: 0.01
# 	Training set of updrs_1 mean absolute error: 0.08
# 	Training set of updrs_1 R^2 score: 0.16
# 	Training set of updrs_2 mean squared error: 0.01
# 	Training set of updrs_2 mean absolute error: 0.05
# 	Training set of updrs_2 R^2 score: 0.02
# 	Training set of updrs_3 mean squared error: 0.00
# 	Training set of updrs_3 mean absolute error: 0.05
# 	Training set of updrs_3 R^2 score: 0.32
# 	Training set of updrs_4 mean squared error: 0.02
# 	Training set of updrs_4 mean absolute error: 0.12
# 	Training set of updrs_4 R^2 score: 0.11
# Training set metrics:
# Patient number: 225
# 	Training set of updrs_1 mean squared error: 0.00
# 	Training set of updrs_1 mean absolute error: 0.02
# 	Training set of updrs_1 R^2 score: 0.02
# 	Training set of updrs_2 mean squared error: 0.00
# 	Training set of updrs_2 mean absolute error: 0.00
# 	Training set of updrs_2 R^2 score: 1.00
# 	Training set of updrs_3 mean squared error: 0.00
# 	Training set of updrs_3 mean absolute error: 0.02
# 	Training set of updrs_3 R^2 score: 0.31
# 	Training set of updrs_4 mean squared error: 0.00
# 	Training set of updrs_4 mean absolute error: 0.00
# 	Training set of updrs_4 R^2 score: 1.00
# Training set metrics:
# Patient number: 226
# 	Training set of updrs_1 mean squared error: 0.01
# 	Training set of updrs_1 mean absolute error: 0.09
# 	Training set of updrs_1 R^2 score: 0.20
# 	Training set of updrs_2 mean squared error: 0.02
# 	Training set of updrs_2 mean absolute error: 0.11
# 	Training set of updrs_2 R^2 score: 0.67
# 	Training set of updrs_3 mean squared error: 0.01
# 	Training set of updrs_3 mean absolute error: 0.07
# 	Training set of updrs_3 R^2 score: 0.59
# 	Training set of updrs_4 mean squared error: 0.00
# 	Training set of updrs_4 mean absolute error: 0.01
# 	Training set of updrs_4 R^2 score: 0.29
# Training set metrics:
# Patient number: 227
# 	Training set of updrs_1 mean squared error: 0.00
# 	Training set of updrs_1 mean absolute error: 0.04
# 	Training set of updrs_1 R^2 score: 0.04
# 	Training set of updrs_2 mean squared error: 0.00
# 	Training set of updrs_2 mean absolute error: 0.03
# 	Training set of updrs_2 R^2 score: 0.05
# 	Training set of updrs_3 mean squared error: 0.00
# 	Training set of updrs_3 mean absolute error: 0.01
# 	Training set of updrs_3 R^2 score: 0.12
# 	Training set of updrs_4 mean squared error: 0.00
# 	Training set of updrs_4 mean absolute error: 0.00
# 	Training set of updrs_4 R^2 score: 1.00
# Training set metrics:
# Patient number: 228
# 	Training set of updrs_1 mean squared error: 0.00
# 	Training set of updrs_1 mean absolute error: 0.03
# 	Training set of updrs_1 R^2 score: 0.71
# 	Training set of updrs_2 mean squared error: 0.00
# 	Training set of updrs_2 mean absolute error: 0.05
# 	Training set of updrs_2 R^2 score: 0.16
# 	Training set of updrs_3 mean squared error: 0.00
# 	Training set of updrs_3 mean absolute error: 0.04
# 	Training set of updrs_3 R^2 score: 0.28
# 	Training set of updrs_4 mean squared error: 0.00
# 	Training set of updrs_4 mean absolute error: 0.00
# 	Training set of updrs_4 R^2 score: 1.00
# Training set metrics:
# Patient number: 229
# 	Training set of updrs_1 mean squared error: 0.00
# 	Training set of updrs_1 mean absolute error: 0.05
# 	Training set of updrs_1 R^2 score: 0.82
# 	Training set of updrs_2 mean squared error: 0.00
# 	Training set of updrs_2 mean absolute error: 0.02
# 	Training set of updrs_2 R^2 score: 0.96
# 	Training set of updrs_3 mean squared error: 0.00
# 	Training set of updrs_3 mean absolute error: 0.03
# 	Training set of updrs_3 R^2 score: 0.39
# 	Training set of updrs_4 mean squared error: 0.01
# 	Training set of updrs_4 mean absolute error: 0.06
# 	Training set of updrs_4 R^2 score: 0.69
# Training set metrics:
# Patient number: 230
# 	Training set of updrs_1 mean squared error: 0.01
# 	Training set of updrs_1 mean absolute error: 0.07
# 	Training set of updrs_1 R^2 score: 0.41
# 	Training set of updrs_2 mean squared error: 0.00
# 	Training set of updrs_2 mean absolute error: 0.03
# 	Training set of updrs_2 R^2 score: 0.04
# 	Training set of updrs_3 mean squared error: 0.00
# 	Training set of updrs_3 mean absolute error: 0.05
# 	Training set of updrs_3 R^2 score: 0.37
# 	Training set of updrs_4 mean squared error: 0.01
# 	Training set of updrs_4 mean absolute error: 0.08
# 	Training set of updrs_4 R^2 score: 0.42
# Training set metrics:
# Patient number: 231
# 	Training set of updrs_1 mean squared error: 0.00
# 	Training set of updrs_1 mean absolute error: 0.05
# 	Training set of updrs_1 R^2 score: 0.04
# 	Training set of updrs_2 mean squared error: 0.00
# 	Training set of updrs_2 mean absolute error: 0.01
# 	Training set of updrs_2 R^2 score: 0.00
# 	Training set of updrs_3 mean squared error: 0.00
# 	Training set of updrs_3 mean absolute error: 0.01
# 	Training set of updrs_3 R^2 score: 0.02
# 	Training set of updrs_4 mean squared error: 0.00
# 	Training set of updrs_4 mean absolute error: 0.00
# 	Training set of updrs_4 R^2 score: 1.00
# Training set metrics:
# Patient number: 232
# 	Training set of updrs_1 mean squared error: 0.00
# 	Training set of updrs_1 mean absolute error: 0.02
# 	Training set of updrs_1 R^2 score: 0.90
# 	Training set of updrs_2 mean squared error: 0.00
# 	Training set of updrs_2 mean absolute error: 0.00
# 	Training set of updrs_2 R^2 score: 1.00
# 	Training set of updrs_3 mean squared error: 0.00
# 	Training set of updrs_3 mean absolute error: 0.01
# 	Training set of updrs_3 R^2 score: 0.02
# 	Training set of updrs_4 mean squared error: 0.00
# 	Training set of updrs_4 mean absolute error: 0.00
# 	Training set of updrs_4 R^2 score: 1.00
# Training set metrics:
# Patient number: 233
# 	Training set of updrs_1 mean squared error: 0.02
# 	Training set of updrs_1 mean absolute error: 0.13
# 	Training set of updrs_1 R^2 score: 0.07
# 	Training set of updrs_2 mean squared error: 0.00
# 	Training set of updrs_2 mean absolute error: 0.03
# 	Training set of updrs_2 R^2 score: 0.52
# 	Training set of updrs_3 mean squared error: 0.00
# 	Training set of updrs_3 mean absolute error: 0.00
# 	Training set of updrs_3 R^2 score: 1.00
# 	Training set of updrs_4 mean squared error: 0.00
# 	Training set of updrs_4 mean absolute error: 0.00
# 	Training set of updrs_4 R^2 score: 1.00
# Training set metrics:
# Patient number: 234
# 	Training set of updrs_1 mean squared error: 0.00
# 	Training set of updrs_1 mean absolute error: 0.04
# 	Training set of updrs_1 R^2 score: 0.11
# 	Training set of updrs_2 mean squared error: 0.00
# 	Training set of updrs_2 mean absolute error: 0.01
# 	Training set of updrs_2 R^2 score: 0.00
# 	Training set of updrs_3 mean squared error: 0.00
# 	Training set of updrs_3 mean absolute error: 0.02
# 	Training set of updrs_3 R^2 score: 0.20
# 	Training set of updrs_4 mean squared error: 0.00
# 	Training set of updrs_4 mean absolute error: 0.00
# 	Training set of updrs_4 R^2 score: 1.00
# Training set metrics:
# Patient number: 235
# 	Training set of updrs_1 mean squared error: 0.00
# 	Training set of updrs_1 mean absolute error: 0.05
# 	Training set of updrs_1 R^2 score: 0.23
# 	Training set of updrs_2 mean squared error: 0.00
# 	Training set of updrs_2 mean absolute error: 0.03
# 	Training set of updrs_2 R^2 score: 0.26
# 	Training set of updrs_3 mean squared error: 0.01
# 	Training set of updrs_3 mean absolute error: 0.06
# 	Training set of updrs_3 R^2 score: 0.61
# 	Training set of updrs_4 mean squared error: 0.00
# 	Training set of updrs_4 mean absolute error: 0.03
# 	Training set of updrs_4 R^2 score: 0.65
# Training set metrics:
# Patient number: 236
# 	Training set of updrs_1 mean squared error: 0.00
# 	Training set of updrs_1 mean absolute error: 0.03
# 	Training set of updrs_1 R^2 score: 0.23
# 	Training set of updrs_2 mean squared error: 0.00
# 	Training set of updrs_2 mean absolute error: 0.05
# 	Training set of updrs_2 R^2 score: 0.50
# 	Training set of updrs_3 mean squared error: 0.01
# 	Training set of updrs_3 mean absolute error: 0.07
# 	Training set of updrs_3 R^2 score: 0.05
# 	Training set of updrs_4 mean squared error: 0.00
# 	Training set of updrs_4 mean absolute error: 0.00
# 	Training set of updrs_4 R^2 score: 1.00
# Training set metrics:
# Patient number: 237
# 	Training set of updrs_1 mean squared error: 0.00
# 	Training set of updrs_1 mean absolute error: 0.02
# 	Training set of updrs_1 R^2 score: 0.26
# 	Training set of updrs_2 mean squared error: 0.00
# 	Training set of updrs_2 mean absolute error: 0.01
# 	Training set of updrs_2 R^2 score: 0.02
# 	Training set of updrs_3 mean squared error: 0.00
# 	Training set of updrs_3 mean absolute error: 0.02
# 	Training set of updrs_3 R^2 score: 0.04
# 	Training set of updrs_4 mean squared error: 0.00
# 	Training set of updrs_4 mean absolute error: 0.00
# 	Training set of updrs_4 R^2 score: 1.00
# Training set metrics:
# Patient number: 238
# 	Training set of updrs_1 mean squared error: 0.00
# 	Training set of updrs_1 mean absolute error: 0.06
# 	Training set of updrs_1 R^2 score: 0.01
# 	Training set of updrs_2 mean squared error: 0.00
# 	Training set of updrs_2 mean absolute error: 0.03
# 	Training set of updrs_2 R^2 score: 0.41
# 	Training set of updrs_3 mean squared error: 0.00
# 	Training set of updrs_3 mean absolute error: 0.00
# 	Training set of updrs_3 R^2 score: 0.43
# 	Training set of updrs_4 mean squared error: 0.00
# 	Training set of updrs_4 mean absolute error: 0.00
# 	Training set of updrs_4 R^2 score: 1.00
# Training set metrics:
# Patient number: 239
# 	Training set of updrs_1 mean squared error: 0.01
# 	Training set of updrs_1 mean absolute error: 0.08
# 	Training set of updrs_1 R^2 score: 0.18
# 	Training set of updrs_2 mean squared error: 0.00
# 	Training set of updrs_2 mean absolute error: 0.03
# 	Training set of updrs_2 R^2 score: 0.47
# 	Training set of updrs_3 mean squared error: 0.00
# 	Training set of updrs_3 mean absolute error: 0.05
# 	Training set of updrs_3 R^2 score: 0.02
# 	Training set of updrs_4 mean squared error: 0.01
# 	Training set of updrs_4 mean absolute error: 0.06
# 	Training set of updrs_4 R^2 score: 0.13
# Training set metrics:
# Patient number: 240
# 	Training set of updrs_1 mean squared error: 0.00
# 	Training set of updrs_1 mean absolute error: 0.03
# 	Training set of updrs_1 R^2 score: 0.05
# 	Training set of updrs_2 mean squared error: 0.00
# 	Training set of updrs_2 mean absolute error: 0.02
# 	Training set of updrs_2 R^2 score: 0.02
# 	Training set of updrs_3 mean squared error: 0.00
# 	Training set of updrs_3 mean absolute error: 0.03
# 	Training set of updrs_3 R^2 score: 0.18
# 	Training set of updrs_4 mean squared error: 0.00
# 	Training set of updrs_4 mean absolute error: 0.03
# 	Training set of updrs_4 R^2 score: 0.58
# Training set metrics:
# Patient number: 241
# 	Training set of updrs_1 mean squared error: 0.00
# 	Training set of updrs_1 mean absolute error: 0.05
# 	Training set of updrs_1 R^2 score: 0.06
# 	Training set of updrs_2 mean squared error: 0.00
# 	Training set of updrs_2 mean absolute error: 0.06
# 	Training set of updrs_2 R^2 score: 0.52
# 	Training set of updrs_3 mean squared error: 0.01
# 	Training set of updrs_3 mean absolute error: 0.08
# 	Training set of updrs_3 R^2 score: 0.20
# 	Training set of updrs_4 mean squared error: 0.03
# 	Training set of updrs_4 mean absolute error: 0.14
# 	Training set of updrs_4 R^2 score: 0.54
# Training set metrics:
# Patient number: 242
# 	Training set of updrs_1 mean squared error: 0.00
# 	Training set of updrs_1 mean absolute error: 0.01
# 	Training set of updrs_1 R^2 score: 0.69
# 	Training set of updrs_2 mean squared error: 0.00
# 	Training set of updrs_2 mean absolute error: 0.01
# 	Training set of updrs_2 R^2 score: 0.79
# 	Training set of updrs_3 mean squared error: 0.00
# 	Training set of updrs_3 mean absolute error: 0.03
# 	Training set of updrs_3 R^2 score: 0.50
# 	Training set of updrs_4 mean squared error: 0.00
# 	Training set of updrs_4 mean absolute error: 0.03
# 	Training set of updrs_4 R^2 score: 0.60
# Training set metrics:
# Patient number: 243
# 	Training set of updrs_1 mean squared error: 0.00
# 	Training set of updrs_1 mean absolute error: 0.04
# 	Training set of updrs_1 R^2 score: 0.15
# 	Training set of updrs_2 mean squared error: 0.00
# 	Training set of updrs_2 mean absolute error: 0.01
# 	Training set of updrs_2 R^2 score: 0.15
# 	Training set of updrs_3 mean squared error: 0.00
# 	Training set of updrs_3 mean absolute error: 0.01
# 	Training set of updrs_3 R^2 score: 0.00
# 	Training set of updrs_4 mean squared error: 0.00
# 	Training set of updrs_4 mean absolute error: 0.00
# 	Training set of updrs_4 R^2 score: 1.00
# Training set metrics:
# Patient number: 244
# 	Training set of updrs_1 mean squared error: 0.00
# 	Training set of updrs_1 mean absolute error: 0.03
# 	Training set of updrs_1 R^2 score: 0.45
# 	Training set of updrs_2 mean squared error: 0.00
# 	Training set of updrs_2 mean absolute error: 0.05
# 	Training set of updrs_2 R^2 score: 0.05
# 	Training set of updrs_3 mean squared error: 0.01
# 	Training set of updrs_3 mean absolute error: 0.09
# 	Training set of updrs_3 R^2 score: 0.03
# 	Training set of updrs_4 mean squared error: 0.00
# 	Training set of updrs_4 mean absolute error: 0.04
# 	Training set of updrs_4 R^2 score: 0.10
# Training set metrics:
# Patient number: 245
# 	Training set of updrs_1 mean squared error: 0.01
# 	Training set of updrs_1 mean absolute error: 0.08
# 	Training set of updrs_1 R^2 score: 0.06
# 	Training set of updrs_2 mean squared error: 0.00
# 	Training set of updrs_2 mean absolute error: 0.05
# 	Training set of updrs_2 R^2 score: 0.06
# 	Training set of updrs_3 mean squared error: 0.01
# 	Training set of updrs_3 mean absolute error: 0.10
# 	Training set of updrs_3 R^2 score: 0.34
# 	Training set of updrs_4 mean squared error: 0.00
# 	Training set of updrs_4 mean absolute error: 0.00
# 	Training set of updrs_4 R^2 score: 1.00
# Training set metrics:
# Patient number: 246
# 	Training set of updrs_1 mean squared error: 0.01
# 	Training set of updrs_1 mean absolute error: 0.07
# 	Training set of updrs_1 R^2 score: 0.16
# 	Training set of updrs_2 mean squared error: 0.01
# 	Training set of updrs_2 mean absolute error: 0.08
# 	Training set of updrs_2 R^2 score: 0.54
# 	Training set of updrs_3 mean squared error: 0.01
# 	Training set of updrs_3 mean absolute error: 0.07
# 	Training set of updrs_3 R^2 score: 0.77
# 	Training set of updrs_4 mean squared error: 0.00
# 	Training set of updrs_4 mean absolute error: 0.03
# 	Training set of updrs_4 R^2 score: 0.81
# Training set metrics:
# Patient number: 247
# 	Training set of updrs_1 mean squared error: 0.00
# 	Training set of updrs_1 mean absolute error: 0.04
# 	Training set of updrs_1 R^2 score: 0.27
# 	Training set of updrs_2 mean squared error: 0.00
# 	Training set of updrs_2 mean absolute error: 0.03
# 	Training set of updrs_2 R^2 score: 0.04
# 	Training set of updrs_3 mean squared error: 0.00
# 	Training set of updrs_3 mean absolute error: 0.04
# 	Training set of updrs_3 R^2 score: 0.00
# 	Training set of updrs_4 mean squared error: 0.00
# 	Training set of updrs_4 mean absolute error: 0.02
# 	Training set of updrs_4 R^2 score: 0.62

# %%
#Create the training database for XGBoost

training_data_XGB = train[(train["visit_month"] == 0)]
training_data_XGB = training_data_XGB.replace('On',1)
training_data_XGB = training_data_XGB.replace('Off',0)


x_training_XGB = training_data_XGB.loc[:, ~training_data_XGB.columns.isin(['visit_month',	'updrs_1',	'updrs_2',	'updrs_3',	'updrs_4'])]
x_training_XGB = x_training_XGB[0:training_length]
y_training_XGB = linear_regressors_list[4][0:training_length]

x_testing_XGB = training_data_XGB.loc[:, ~training_data_XGB.columns.isin(['visit_month',	'updrs_1',	'updrs_2',	'updrs_3',	'updrs_4'])]
x_testing_XGB = x_testing_XGB[-training_length:]
y_testing_XGB = linear_regressors_list[4][-training_length:]

x_training_XGB.head(20)
# Out:
#             upd23b_clinical_state_on_medication    O00391    O00533    O00584  \
# patient_id
# 55                                            1  0.506663  0.385009  0.589438
# 942                                           0  0.504925  0.194476  0.296838
# 1517                                          1  0.525923  0.205634  0.519663
# 1923                                          0  1.000000  0.462018  0.473187
# 2660                                          0  0.714682  0.297672  0.415062
# 3636                                          1  0.488735  0.118862  0.155339
# 3863                                          1  0.562954  0.358669  0.402434
# 4161                                          0  0.559469  0.580927  0.365294
# 4172                                          0  0.422016  0.222161  0.338409
# 4923                                          1  0.376161  0.120490  0.430597
# 5027                                          0  0.352993  0.178220  0.114631
# 5036                                          0  0.643148  0.222580  0.243771
# 5178                                          0  0.488770  0.355144  0.422609
# 5645                                          0  0.437961  0.274813  0.535275
# 5742                                          0  0.318808  0.093781  0.277365
# 6054                                          0  0.301159  0.069627  0.357502
# 6211                                          0  0.518766  0.072866  0.263442
# 6420                                          0  0.354859  0.110120  0.304074
# 7051                                          0  0.535480  0.138795  0.240983
# 7117                                          0  0.626616  0.198224  0.272834
#
#               O14498    O14773    O14791    O15240    O15394    O43505  ...  \
# patient_id                                                              ...
# 55          0.577661  0.606317  0.428809  0.323142  0.433950  0.412072  ...
# 942         0.396180  0.071718  0.247097  0.289777  0.285920  0.184275  ...
# 1517        0.223315  0.312581  0.271501  0.208973  0.261991  0.185358  ...
# 1923        0.797091  0.225277  0.292549  0.499804  0.575951  0.388137  ...
# 2660        0.371222  0.348153  0.171703  0.239258  0.492983  0.249106  ...
# 3636        0.119692  0.081798  0.291293  0.098336  0.152939  0.058214  ...
# 3863        0.523169  0.427900  0.002625  0.307837  0.487622  0.269355  ...
# 4161        0.779948  0.129385  0.204484  0.462008  0.298862  0.183795  ...
# 4172        0.254559  0.429852  0.189084  0.126402  0.279981  0.229866  ...
# 4923        0.144390  0.399603  0.305278  0.125601  0.030652  0.209754  ...
# 5027        0.127307  0.585735  0.253924  0.143374  0.435552  0.164337  ...
# 5036        0.242963  0.188239  0.438003  0.149200  0.345471  0.173573  ...
# 5178        0.355435  0.387910  0.211418  0.301470  0.354928  0.253623  ...
# 5645        0.316088  0.875831  0.264058  0.317228  0.448012  0.319441  ...
# 5742        0.322797  0.113757  0.245589  0.156876  0.333496  0.097514  ...
# 6054        0.123270  0.347995  0.438765  0.134466  0.215058  0.207786  ...
# 6211        0.187152  0.034331  0.143208  0.055427  0.056008  0.095773  ...
# 6420        0.152512  0.462735  0.213327  0.155629  0.027931  0.129773  ...
# 7051        0.167070  0.189205  0.422527  0.182030  0.220387  0.171192  ...
# 7117        0.107326  0.255304  0.491638  0.220679  0.251513  0.106030  ...
#
#             YSLTYIYTGLSK   YTTEIIK  YVGGQEHFAHLLILR  \
# patient_id
# 55              0.475128  0.592219         0.266399
# 942             0.538369  0.224044         0.015471
# 1517            0.498007  0.238256         0.277087
# 1923            0.763587  0.622074         0.193434
# 2660            0.699041  0.232309         0.437992
# 3636            0.496097  0.000000         0.300775
# 3863            0.142158  0.494503         0.058131
# 4161            0.471952  0.245764         0.579690
# 4172            0.387545  0.359217         0.120132
# 4923            0.490018  0.261019         0.048818
# 5027            0.589461  0.341845         0.341656
# 5036            0.315851  0.395577         0.137840
# 5178            0.635623  0.321162         0.246264
# 5645            0.339488  0.327628         0.217935
# 5742            0.483959  0.179216         0.191156
# 6054            0.377678  0.297007         0.162164
# 6211            0.568444  0.184070         0.226110
# 6420            0.530596  0.199977         0.264115
# 7051            0.587012  0.159562         0.391825
# 7117            0.585142  0.169358         0.290673
#
#             YVM(UniMod_35)LPVADQDQC(UniMod_4)IR  YVMLPVADQDQC(UniMod_4)IR  \
# patient_id
# 55                                     0.148896                  0.144114
# 942                                    0.079620                  0.119042
# 1517                                   0.140714                  0.191079
# 1923                                   0.081710                  0.104645
# 2660                                   0.020612                  0.028934
# 3636                                   0.132498                  0.413796
# 3863                                   0.195825                  0.370944
# 4161                                   0.069932                  0.124683
# 4172                                   0.072683                  0.110422
# 4923                                   0.097825                  0.134342
# 5027                                   0.083211                  0.105029
# 5036                                   0.008583                  0.031646
# 5178                                   0.021192                  0.051275
# 5645                                   0.022141                  0.131065
# 5742                                   0.096748                  0.560959
# 6054                                   0.023627                  0.038181
# 6211                                   0.077890                  0.182541
# 6420                                   0.073437                  0.053566
# 7051                                   0.145803                  0.155964
# 7117                                   0.075392                  0.085363
#
#             YVNKEIQNAVNGVK  YWGVASFLQK  YYC(UniMod_4)FQGNQFLR  YYTYLIMNK  \
# patient_id
# 55                0.519776    0.626289               0.454550   0.395872
# 942               0.315697    0.298863               0.599682   0.412893
# 1517              0.258495    0.429223               0.487557   0.380823
# 1923              0.435122    0.598925               0.484351   0.610626
# 2660              0.326011    0.453343               0.433641   0.331067
# 3636              0.240055    0.399413               0.298753   0.169698
# 3863              0.383159    0.487818               0.503854   0.444482
# 4161              0.507257    0.266723               0.380110   0.180975
# 4172              0.269330    0.540585               0.507366   0.498842
# 4923              0.385314    0.503393               0.511037   0.370833
# 5027              0.246444    0.820300               0.198515   0.586262
# 5036              0.269667    0.548065               0.198902   0.540148
# 5178              0.411018    0.692865               0.553002   0.546975
# 5645              0.388836    0.379765               0.480072   0.297013
# 5742              0.291715    0.559868               0.448735   0.268372
# 6054              0.266488    0.458619               0.480761   0.222885
# 6211              0.268021    0.276066               0.337259   0.219991
# 6420              0.444406    0.371104               0.434046   0.347214
# 7051              0.275000    0.467152               0.667864   0.447325
# 7117              0.276946    0.540376               0.675991   0.517501
#
#             YYWGGQYTWDMAK
# patient_id
# 55               0.202879
# 942              0.214097
# 1517             0.286704
# 1923             0.078405
# 2660             0.327138
# 3636             0.351583
# 3863             0.282796
# 4161             0.110287
# 4172             0.344011
# 4923             0.009196
# 5027             0.265967
# 5036             0.398508
# 5178             0.338371
# 5645             0.311115
# 5742             0.456381
# 6054             0.205748
# 6211             0.224322
# 6420             0.132860
# 7051             0.981153
# 7117             0.415869
#
# [20 rows x 1196 columns]

# %%
# Try to predict the regression values from proteins using XGBOOST
params = {
    "n_estimators": 500,
    "max_depth": 4,
    "min_samples_split": 5,
    "learning_rate": 0.01,
    "loss": "squared_error",
}
XGBModel = sklearn.ensemble.GradientBoostingRegressor(**params)
XGBModel.fit(x_training_XGB, y_training_XGB)

mse = mean_squared_error(y_testing_XGB, XGBModel.predict(x_testing_XGB))
print("The mean squared error (MSE) on test set: {:.4f}".format(mse))
# Out:
# The mean squared error (MSE) on test set: 0.0000

# %%
# Visualize the results

test_score = np.zeros((params["n_estimators"],), dtype=np.float64)
for i, y_pred in enumerate(XGBModel.staged_predict(x_testing_XGB)):
    test_score[i] = mean_squared_error(y_testing_XGB, y_pred)

fig = plt.figure(figsize=(6, 6))
plt.subplot(1, 1, 1)
plt.title("Deviance")
plt.plot(
    np.arange(params["n_estimators"]) + 1,
    XGBModel.train_score_,
    "b-",
    label="Training Set Deviance",
)
plt.plot(
    np.arange(params["n_estimators"]) + 1, test_score, "r-", label="Test Set Deviance"
)
plt.legend(loc="upper right")
plt.xlabel("Boosting Iterations")
plt.ylabel("Deviance")
fig.tight_layout()
plt.show()

# %%
print(train.columns[6:])
# Out:
# Index(['O00391', 'O00533', 'O00584', 'O14498', 'O14773', 'O14791', 'O15240',
#        'O15394', 'O43505', 'O60888',
#        ...
#        'YSLTYIYTGLSK', 'YTTEIIK', 'YVGGQEHFAHLLILR',
#        'YVM(UniMod_35)LPVADQDQC(UniMod_4)IR', 'YVMLPVADQDQC(UniMod_4)IR',
#        'YVNKEIQNAVNGVK', 'YWGVASFLQK', 'YYC(UniMod_4)FQGNQFLR', 'YYTYLIMNK',
#        'YYWGGQYTWDMAK'],
#       dtype='object', length=1195)

# %%
# Now we will use a regression model to predict the updrs based on protein levels
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(train[train.columns[6:]], train.updrs_1, test_size=0.2, random_state=42)

# Create a Random Forest Regressor object with default parameters
rf1 = RandomForestRegressor()

# Fit the model to the training data
rf1.fit(X_train, y_train)

# Make predictions on the test data
y_pred = rf1.predict(X_test)

# Evaluate the model using Mean Absolute Error (MAE)
from sklearn.metrics import mean_absolute_error
mae = mean_absolute_error(y_test, y_pred)
print('Mean Absolute Error of updrs 1:', mae)

# plot feature importance graph
plt.bar(range(len(rf1.feature_importances_)), rf1.feature_importances_)
plt.show()
# Out:
# C:\Users\vbovedap\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# Mean Absolute Error of updrs 1: 0.0850312375047296

# %%
X_train, X_test, y_train, y_test = train_test_split(train[train.columns[6:]], train.updrs_2, test_size=0.2, random_state=42)

# Create a Random Forest Regressor object with default parameters
rf2 = RandomForestRegressor()

# Fit the model to the training data
rf2.fit(X_train, y_train)

# Make predictions on the test data
y_pred = rf2.predict(X_test)

# Evaluate the model using Mean Absolute Error (MAE)
from sklearn.metrics import mean_absolute_error
mae = mean_absolute_error(y_test, y_pred)
print('Mean Absolute Error of updrs 2:', mae)

# plot feature importance graph
plt.bar(range(len(rf2.feature_importances_)), rf2.feature_importances_)
plt.show()
# Out:
# C:\Users\vbovedap\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# Mean Absolute Error of updrs 2: 0.07271354145111314

# %%
X_train, X_test, y_train, y_test = train_test_split(train[train.columns[6:]], train.updrs_3, test_size=0.2, random_state=42)

# Create a Random Forest Regressor object with default parameters
rf3 = RandomForestRegressor()

# Fit the model to the training data
rf3.fit(X_train, y_train)

# Make predictions on the test data
y_pred = rf3.predict(X_test)

# Evaluate the model using Mean Absolute Error (MAE)
from sklearn.metrics import mean_absolute_error
mae = mean_absolute_error(y_test, y_pred)
print('Mean Absolute Error of updrs 3:', mae)

# plot feature importance graph
plt.bar(range(len(rf3.feature_importances_)), rf3.feature_importances_)
plt.show()
# Out:
# C:\Users\vbovedap\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# Mean Absolute Error of updrs 3: 0.08553644943502207

# %%
X_train, X_test, y_train, y_test = train_test_split(train[train.columns[6:]], train.updrs_4, test_size=0.2, random_state=42)

# Create a Random Forest Regressor object with default parameters
rf4 = RandomForestRegressor()

# Fit the model to the training data
rf4.fit(X_train, y_train)

# Make predictions on the test data
y_pred = rf4.predict(X_test)

# Evaluate the model using Mean Absolute Error (MAE)
from sklearn.metrics import mean_absolute_error
mae = mean_absolute_error(y_test, y_pred)
print('Mean Absolute Error of updrs 4:', mae)

# plot feature importance graph
plt.bar(range(len(rf4.feature_importances_)), rf4.feature_importances_)
plt.show()
# Out:
# C:\Users\vbovedap\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# Mean Absolute Error of updrs 4: 0.059945214759746304

# %%
print(train.updrs_1)
# Out:
# patient_id
# 55       0.303030
# 55       0.303030
# 55       0.242424
# 55       0.242424
# 55       0.303030
#            ...
# 65043    0.212121
# 65043    0.121212
# 65043    0.181818
# 65043    0.090909
# 65043    0.212121
# Name: updrs_1, Length: 2615, dtype: float64

# %%
print(y_pred)
# Out:
# [0.095      0.055      0.         0.         0.         0.3
#  0.06       0.15       0.07616667 0.         0.         0.01875
#  0.165      0.08416667 0.01178571 0.095      0.015      0.099
#  0.         0.025      0.225      0.015      0.035      0.025
#  0.         0.         0.02       0.075      0.13       0.
#  0.02766667 0.02111111 0.0125     0.01333333 0.         0.
#  0.31233333 0.055      0.025      0.         0.         0.08225
#  0.095      0.0625     0.16997222 0.         0.         0.07466667
#  0.025      0.00125    0.         0.09       0.         0.23833333
#  0.         0.035      0.17       0.035      0.03       0.095
#  0.         0.         0.         0.         0.02       0.
#  0.32916667 0.01       0.12       0.17833333 0.775      0.
#  0.025      0.         0.19428571 0.18875    0.         0.
#  0.         0.015      0.         0.545      0.         0.
#  0.         0.18666667 0.         0.         0.20803571 0.22625
#  0.015      0.29571429 0.         0.0815     0.05583333 0.025
#  0.0075     0.38096825 0.         0.         0.16       0.
#  0.055      0.025      0.0175     0.38096825 0.065      0.
#  0.06       0.         0.235      0.20316667 0.01552778 0.
#  0.         0.083      0.02       0.05875    0.16       0.04
#  0.04722222 0.00125    0.01       0.035      0.         0.037
#  0.         0.02       0.47153571 0.         0.29148485 0.025
#  0.11       0.         0.02708333 0.         0.         0.28416667
#  0.         0.02833333 0.00780128 0.26       0.08333333 0.
#  0.025      0.16       0.10704762 0.         0.055      0.20055159
#  0.         0.         0.03       0.045      0.         0.
#  0.03       0.1985     0.025      0.         0.19       0.02
#  0.         0.         0.055      0.         0.         0.0375
#  0.13277778 0.005      0.         0.245      0.145      0.
#  0.1575     0.01785714 0.         0.         0.135      0.
#  0.015      0.07       0.1        0.235      0.02       0.04
#  0.075      0.055      0.03857143 0.         0.165      0.
#  0.         0.04875    0.165      0.055      0.         0.16
#  0.04833333 0.         0.02       0.025      0.4        0.025
#  0.001      0.03833333 0.165      0.         0.23166667 0.
#  0.         0.         0.035      0.01       0.0325     0.
#  0.02       0.         0.04       0.06       0.00375    0.045
#  0.09484524 0.07       0.03583333 0.24       0.18666667 0.
#  0.12922222 0.04       0.005      0.045      0.01552778 0.05
#  0.00666667 0.15428571 0.         0.148      0.04       0.00166667
#  0.         0.         0.008      0.08333333 0.         0.165
#  0.005      0.         0.         0.175      0.365      0.025
#  0.08       0.02458333 0.         0.         0.         0.12833333
#  0.01       0.         0.00916667 0.035      0.         0.018
#  0.         0.         0.         0.         0.05333333 0.
#  0.07361111 0.03416667 0.01       0.         0.         0.16
#  0.         0.035      0.10041667 0.1675     0.10125    0.1355
#  0.         0.26785714 0.         0.10916667 0.         0.
#  0.015      0.         0.07097222 0.19       0.         0.215
#  0.         0.         0.31       0.         0.015      0.01375
#  0.         0.         0.07       0.01166667 0.11       0.07
#  0.02       0.115      0.29148485 0.095      0.00780128 0.175
#  0.03       0.04       0.055      0.065      0.085      0.
#  0.15       0.         0.105      0.02       0.01       0.055
#  0.065      0.29148485 0.03857143 0.         0.00666667 0.14978175
#  0.4        0.17525    0.055      0.18875    0.         0.07
#  0.01       0.12       0.02       0.22       0.015      0.22
#  0.05375    0.03857143 0.09       0.01552778 0.065      0.01
#  0.015      0.16       0.035      0.015      0.015      0.
#  0.         0.03166667 0.         0.055      0.03857143 0.015
#  0.035      0.08120238 0.03833333 0.         0.         0.01
#  0.06725    0.00214286 0.07       0.13041667 0.08       0.
#  0.152      0.         0.367      0.         0.13333333 0.
#  0.06791667 0.175      0.17525    0.05       0.         0.03442857
#  0.015      0.         0.         0.08       0.01516667 0.
#  0.12       0.00583333 0.         0.45       0.05       0.22833333
#  0.005      0.005      0.         0.         0.         0.
#  0.20055159 0.205      0.085      0.05111111 0.0475     0.01
#  0.         0.01       0.         0.         0.1675     0.025
#  0.16333333 0.03442857 0.04410714 0.         0.         0.03
#  0.         0.08120238 0.065      0.         0.         0.04
#  0.46666667 0.         0.16       0.02       0.         0.0635
#  0.         0.01666667 0.         0.38096825 0.         0.31233333
#  0.06166667 0.         0.         0.         0.         0.
#  0.095      0.14978175 0.         0.03264286 0.09       0.
#  0.         0.07       0.13       0.         0.17       0.
#  0.         0.00166667 0.01516667 0.38233333 0.02333333 0.
#  0.0225     0.24       0.         0.22       0.06       0.145
#  0.025      0.14978175 0.005      0.106      0.025      0.025
#  0.         0.005      0.         0.2165     0.         0.115
#  0.         0.         0.08       0.305      0.13214286 0.
#  0.035      0.05271429 0.025      0.15166667 0.024      0.28416667
#  0.09166667 0.         0.         0.05333333 0.         0.04
#  0.         0.005      0.04       0.135      0.0575     0.195
#  0.         0.16625    0.02       0.         0.36005952 0.04
#  0.036      0.         0.065      0.         0.495      0.
#  0.0975     0.04875    0.195      0.02       0.13166667 0.075
#  0.095     ]

# %%
print(y_test)
# Out:
# patient_id
# 64674    0.20
# 24820    0.05
# 56317    0.00
# 26210    0.00
# 49683    0.00
#          ...
# 13618    0.25
# 60326    0.00
# 12931    0.00
# 30416    0.05
# 64674    0.30
# Name: updrs_4, Length: 523, dtype: float64
